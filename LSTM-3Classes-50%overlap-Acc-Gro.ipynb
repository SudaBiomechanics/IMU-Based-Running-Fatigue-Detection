# %% [markdown]
# # LSTM-3Classes-Acc

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-50%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-50%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (34334, 200, 9)
# (34334, 1)

# %%
#只取前六列Acc数据
X_train=X_train[:,:,0:6]#只取前六列Acc数据
print(X_train.shape)
print(Y_train.shape)
# Out:
# (34334, 200, 6)
# (34334, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (30900, 200, 6)
# (30900, 1)
# (3434, 200, 6)
# (3434, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
## Import Keras
from __future__ import print_function
import keras
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
from attention import Attention
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

# %% [markdown]
# **LSTM Model**

# %%
# Initiliazing the sequential model
model2 = Sequential()
# Configuring the parameters
model2.add(LSTM(128, return_sequences=False, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal'))
# Adding a dropout layer
model2.add(Dropout(0.5))
#model2.add(Attention(64))
# #model2.add(BatchNormalization())
# model2.add(LSTM(64))
# # Adding a dropout layer
# model2.add(Dropout(0.5))
# # Adding a dense output layer with sigmoid activation
model2.add(Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))

model2.summary()
#-------------------
# Compiling the model
model2.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])#

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_loss', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.25,
    patience=8,#
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list =[mc,es,rp]
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               69120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 387
# =================================================================
# Total params: 69,507
# Trainable params: 69,507
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
#model2.load_weights("M2-weights-improvement-23-0.70.hdf5")
history=model2.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          validation_data=None,
          shuffle=True,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 27810 samples, validate on 3090 samples
# Epoch 1/200
# 27810/27810 [==============================] - ETA: 0s - loss: 1.1623 - acc: 0.3921WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.42104, saving model to M2-weights-improvement-01-0.42.hdf5
# 27810/27810 [==============================] - 68s 2ms/sample - loss: 1.1623 - acc: 0.3921 - val_loss: 1.0794 - val_acc: 0.4210
# Epoch 2/200
# 27810/27810 [==============================] - ETA: 0s - loss: 1.0618 - acc: 0.4382
# Epoch 00002: val_acc improved from 0.42104 to 0.50065, saving model to M2-weights-improvement-02-0.50.hdf5
# 27810/27810 [==============================] - 69s 2ms/sample - loss: 1.0618 - acc: 0.4382 - val_loss: 0.9861 - val_acc: 0.5006
# Epoch 3/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.9749 - acc: 0.5043
# Epoch 00003: val_acc improved from 0.50065 to 0.50906, saving model to M2-weights-improvement-03-0.51.hdf5
# 27810/27810 [==============================] - 71s 3ms/sample - loss: 0.9749 - acc: 0.5043 - val_loss: 0.9687 - val_acc: 0.5091
# Epoch 4/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.9087 - acc: 0.5521
# Epoch 00004: val_acc improved from 0.50906 to 0.55502, saving model to M2-weights-improvement-04-0.56.hdf5
# 27810/27810 [==============================] - 81s 3ms/sample - loss: 0.9087 - acc: 0.5521 - val_loss: 0.8933 - val_acc: 0.5550
# Epoch 5/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.8420 - acc: 0.5977
# Epoch 00005: val_acc improved from 0.55502 to 0.62621, saving model to M2-weights-improvement-05-0.63.hdf5
# 27810/27810 [==============================] - 76s 3ms/sample - loss: 0.8420 - acc: 0.5977 - val_loss: 0.8013 - val_acc: 0.6262
# Epoch 6/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.7831 - acc: 0.6385
# Epoch 00006: val_acc improved from 0.62621 to 0.68544, saving model to M2-weights-improvement-06-0.69.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.7831 - acc: 0.6385 - val_loss: 0.7172 - val_acc: 0.6854
# Epoch 7/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.7334 - acc: 0.6735
# Epoch 00007: val_acc improved from 0.68544 to 0.71780, saving model to M2-weights-improvement-07-0.72.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.7334 - acc: 0.6735 - val_loss: 0.6780 - val_acc: 0.7178
# Epoch 8/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.6952 - acc: 0.7002
# Epoch 00008: val_acc did not improve from 0.71780
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.6952 - acc: 0.7002 - val_loss: 0.6786 - val_acc: 0.7113
# Epoch 9/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.6550 - acc: 0.7350
# Epoch 00009: val_acc did not improve from 0.71780
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.6550 - acc: 0.7350 - val_loss: 0.6646 - val_acc: 0.7159
# Epoch 10/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.6236 - acc: 0.7516
# Epoch 00010: val_acc did not improve from 0.71780
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.6236 - acc: 0.7516 - val_loss: 0.6791 - val_acc: 0.7091
# Epoch 11/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5895 - acc: 0.7724
# Epoch 00011: val_acc improved from 0.71780 to 0.80162, saving model to M2-weights-improvement-11-0.80.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.5895 - acc: 0.7724 - val_loss: 0.5301 - val_acc: 0.8016
# Epoch 12/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5650 - acc: 0.7844
# Epoch 00012: val_acc did not improve from 0.80162
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.5650 - acc: 0.7844 - val_loss: 0.8650 - val_acc: 0.6320
# Epoch 13/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5419 - acc: 0.7973
# Epoch 00013: val_acc did not improve from 0.80162
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.5419 - acc: 0.7973 - val_loss: 0.5709 - val_acc: 0.7777
# Epoch 14/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5288 - acc: 0.8069
# Epoch 00014: val_acc improved from 0.80162 to 0.82395, saving model to M2-weights-improvement-14-0.82.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.5288 - acc: 0.8069 - val_loss: 0.4867 - val_acc: 0.8239
# Epoch 15/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4992 - acc: 0.8199
# Epoch 00015: val_acc did not improve from 0.82395
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4992 - acc: 0.8199 - val_loss: 0.5608 - val_acc: 0.7786
# Epoch 16/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4789 - acc: 0.8294
# Epoch 00016: val_acc did not improve from 0.82395
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4789 - acc: 0.8294 - val_loss: 0.4859 - val_acc: 0.8178
# Epoch 17/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4574 - acc: 0.8402
# Epoch 00017: val_acc did not improve from 0.82395
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4574 - acc: 0.8402 - val_loss: 0.6377 - val_acc: 0.7518
# Epoch 18/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4387 - acc: 0.8474
# Epoch 00018: val_acc did not improve from 0.82395
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4387 - acc: 0.8474 - val_loss: 0.4841 - val_acc: 0.8204
# Epoch 19/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4348 - acc: 0.8516
# Epoch 00019: val_acc improved from 0.82395 to 0.83786, saving model to M2-weights-improvement-19-0.84.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4348 - acc: 0.8516 - val_loss: 0.4671 - val_acc: 0.8379
# Epoch 20/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4031 - acc: 0.8639
# Epoch 00020: val_acc improved from 0.83786 to 0.86408, saving model to M2-weights-improvement-20-0.86.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.4031 - acc: 0.8639 - val_loss: 0.3936 - val_acc: 0.8641
# Epoch 21/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3962 - acc: 0.8688
# Epoch 00021: val_acc did not improve from 0.86408
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.3962 - acc: 0.8688 - val_loss: 0.5021 - val_acc: 0.8210
# Epoch 22/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3793 - acc: 0.8764
# Epoch 00022: val_acc improved from 0.86408 to 0.88155, saving model to M2-weights-improvement-22-0.88.hdf5
# 27810/27810 [==============================] - 77s 3ms/sample - loss: 0.3793 - acc: 0.8764 - val_loss: 0.3606 - val_acc: 0.8816
# Epoch 23/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3776 - acc: 0.8771
# Epoch 00023: val_acc did not improve from 0.88155
# 27810/27810 [==============================] - 77s 3ms/sample - loss: 0.3776 - acc: 0.8771 - val_loss: 0.3921 - val_acc: 0.8731
# Epoch 24/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3692 - acc: 0.8816
# Epoch 00024: val_acc did not improve from 0.88155
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.3692 - acc: 0.8816 - val_loss: 0.4414 - val_acc: 0.8466
# Epoch 25/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3599 - acc: 0.8842
# Epoch 00025: val_acc did not improve from 0.88155
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.3599 - acc: 0.8842 - val_loss: 0.4901 - val_acc: 0.8243
# Epoch 26/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3455 - acc: 0.8907
# Epoch 00026: val_acc improved from 0.88155 to 0.88641, saving model to M2-weights-improvement-26-0.89.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.3455 - acc: 0.8907 - val_loss: 0.3396 - val_acc: 0.8864
# Epoch 27/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3312 - acc: 0.8964
# Epoch 00027: val_acc did not improve from 0.88641
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.3312 - acc: 0.8964 - val_loss: 0.4028 - val_acc: 0.8628
# Epoch 28/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3224 - acc: 0.9005
# Epoch 00028: val_acc improved from 0.88641 to 0.88673, saving model to M2-weights-improvement-28-0.89.hdf5
# 27810/27810 [==============================] - 86s 3ms/sample - loss: 0.3224 - acc: 0.9005 - val_loss: 0.3541 - val_acc: 0.8867
# Epoch 29/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3183 - acc: 0.9010
# Epoch 00029: val_acc did not improve from 0.88673
# 27810/27810 [==============================] - 78s 3ms/sample - loss: 0.3183 - acc: 0.9010 - val_loss: 0.3890 - val_acc: 0.8722
# Epoch 30/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3165 - acc: 0.9056
# Epoch 00030: val_acc improved from 0.88673 to 0.89385, saving model to M2-weights-improvement-30-0.89.hdf5
# 27810/27810 [==============================] - 78s 3ms/sample - loss: 0.3165 - acc: 0.9056 - val_loss: 0.3328 - val_acc: 0.8939
# Epoch 31/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3031 - acc: 0.9074
# Epoch 00031: val_acc did not improve from 0.89385
# 27810/27810 [==============================] - 79s 3ms/sample - loss: 0.3031 - acc: 0.9074 - val_loss: 0.3767 - val_acc: 0.8799
# Epoch 32/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2929 - acc: 0.9125
# Epoch 00032: val_acc improved from 0.89385 to 0.89547, saving model to M2-weights-improvement-32-0.90.hdf5
# 27810/27810 [==============================] - 80s 3ms/sample - loss: 0.2929 - acc: 0.9125 - val_loss: 0.3197 - val_acc: 0.8955
# Epoch 33/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2871 - acc: 0.9163
# Epoch 00033: val_acc did not improve from 0.89547
# 27810/27810 [==============================] - 76s 3ms/sample - loss: 0.2871 - acc: 0.9163 - val_loss: 0.3806 - val_acc: 0.8864
# Epoch 34/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2769 - acc: 0.9210
# Epoch 00034: val_acc did not improve from 0.89547
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2769 - acc: 0.9210 - val_loss: 0.3655 - val_acc: 0.8880
# Epoch 35/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2760 - acc: 0.9178
# Epoch 00035: val_acc did not improve from 0.89547
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.2760 - acc: 0.9178 - val_loss: 0.4863 - val_acc: 0.8460
# Epoch 36/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2663 - acc: 0.9245
# Epoch 00036: val_acc improved from 0.89547 to 0.89773, saving model to M2-weights-improvement-36-0.90.hdf5
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2663 - acc: 0.9245 - val_loss: 0.3247 - val_acc: 0.8977
# Epoch 37/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2619 - acc: 0.9261
# Epoch 00037: val_acc did not improve from 0.89773
# 27810/27810 [==============================] - 76s 3ms/sample - loss: 0.2619 - acc: 0.9261 - val_loss: 0.3511 - val_acc: 0.8955
# Epoch 38/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2548 - acc: 0.9294
# Epoch 00038: val_acc did not improve from 0.89773
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2548 - acc: 0.9294 - val_loss: 0.4203 - val_acc: 0.8715
# Epoch 39/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2441 - acc: 0.9327
# Epoch 00039: val_acc did not improve from 0.89773
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2441 - acc: 0.9327 - val_loss: 0.3120 - val_acc: 0.8977
# Epoch 40/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2438 - acc: 0.9328
# Epoch 00040: val_acc improved from 0.89773 to 0.91068, saving model to M2-weights-improvement-40-0.91.hdf5
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2438 - acc: 0.9328 - val_loss: 0.3016 - val_acc: 0.9107
# Epoch 41/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2350 - acc: 0.9357
# Epoch 00041: val_acc did not improve from 0.91068
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2350 - acc: 0.9357 - val_loss: 0.3027 - val_acc: 0.9049
# Epoch 42/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2308 - acc: 0.9373
# Epoch 00042: val_acc did not improve from 0.91068
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2308 - acc: 0.9373 - val_loss: 0.3272 - val_acc: 0.9029
# Epoch 43/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2280 - acc: 0.9397
# Epoch 00043: val_acc improved from 0.91068 to 0.91133, saving model to M2-weights-improvement-43-0.91.hdf5
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2280 - acc: 0.9397 - val_loss: 0.3078 - val_acc: 0.9113
# Epoch 44/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2303 - acc: 0.9389
# Epoch 00044: val_acc did not improve from 0.91133
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2303 - acc: 0.9389 - val_loss: 0.3592 - val_acc: 0.8822
# Epoch 45/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2213 - acc: 0.9417
# Epoch 00045: val_acc did not improve from 0.91133
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.2213 - acc: 0.9417 - val_loss: 0.3212 - val_acc: 0.9016
# Epoch 46/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2172 - acc: 0.9435
# Epoch 00046: val_acc did not improve from 0.91133
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.2172 - acc: 0.9435 - val_loss: 0.3289 - val_acc: 0.8948
# Epoch 47/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2118 - acc: 0.9453
# Epoch 00047: val_acc did not improve from 0.91133
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.2118 - acc: 0.9453 - val_loss: 0.3232 - val_acc: 0.8997
# Epoch 48/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2072 - acc: 0.9464
# Epoch 00048: val_acc did not improve from 0.91133
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.2072 - acc: 0.9464 - val_loss: 0.3120 - val_acc: 0.9091
# Epoch 49/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1525 - acc: 0.9675
# Epoch 00049: val_acc improved from 0.91133 to 0.92395, saving model to M2-weights-improvement-49-0.92.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1525 - acc: 0.9675 - val_loss: 0.2841 - val_acc: 0.9239
# Epoch 50/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1299 - acc: 0.9748
# Epoch 00050: val_acc did not improve from 0.92395
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1299 - acc: 0.9748 - val_loss: 0.2811 - val_acc: 0.9201
# Epoch 51/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1209 - acc: 0.9779
# Epoch 00051: val_acc did not improve from 0.92395
# 27810/27810 [==============================] - 79s 3ms/sample - loss: 0.1209 - acc: 0.9779 - val_loss: 0.3131 - val_acc: 0.9201
# Epoch 52/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1165 - acc: 0.9803
# Epoch 00052: val_acc did not improve from 0.92395
# 27810/27810 [==============================] - 81s 3ms/sample - loss: 0.1165 - acc: 0.9803 - val_loss: 0.2995 - val_acc: 0.9233
# Epoch 53/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1145 - acc: 0.9814
# Epoch 00053: val_acc improved from 0.92395 to 0.92589, saving model to M2-weights-improvement-53-0.93.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1145 - acc: 0.9814 - val_loss: 0.2878 - val_acc: 0.9259
# Epoch 54/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1096 - acc: 0.9820
# Epoch 00054: val_acc did not improve from 0.92589
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1096 - acc: 0.9820 - val_loss: 0.2935 - val_acc: 0.9252
# Epoch 55/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1067 - acc: 0.9833
# Epoch 00055: val_acc did not improve from 0.92589
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1067 - acc: 0.9833 - val_loss: 0.2953 - val_acc: 0.9249
# Epoch 56/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1034 - acc: 0.9848
# Epoch 00056: val_acc did not improve from 0.92589
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1034 - acc: 0.9848 - val_loss: 0.3122 - val_acc: 0.9239
# Epoch 57/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1020 - acc: 0.9844
# Epoch 00057: val_acc improved from 0.92589 to 0.93010, saving model to M2-weights-improvement-57-0.93.hdf5
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1020 - acc: 0.9844 - val_loss: 0.2844 - val_acc: 0.9301
# Epoch 58/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1002 - acc: 0.9854
# Epoch 00058: val_acc did not improve from 0.93010
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.1002 - acc: 0.9854 - val_loss: 0.2974 - val_acc: 0.9288
# Epoch 59/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0923 - acc: 0.9882
# Epoch 00059: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.0923 - acc: 0.9882 - val_loss: 0.3072 - val_acc: 0.9285
# Epoch 60/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0876 - acc: 0.9897
# Epoch 00060: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 75s 3ms/sample - loss: 0.0876 - acc: 0.9897 - val_loss: 0.3012 - val_acc: 0.9291
# Epoch 61/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0859 - acc: 0.9905
# Epoch 00061: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.0859 - acc: 0.9905 - val_loss: 0.3093 - val_acc: 0.9269
# Epoch 62/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0854 - acc: 0.9907
# Epoch 00062: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.0854 - acc: 0.9907 - val_loss: 0.3105 - val_acc: 0.9282
# Epoch 63/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0842 - acc: 0.9907
# Epoch 00063: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.0842 - acc: 0.9907 - val_loss: 0.3142 - val_acc: 0.9275
# Epoch 64/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0819 - acc: 0.9920
# Epoch 00064: val_acc did not improve from 0.93010
# 27810/27810 [==============================] - 74s 3ms/sample - loss: 0.0819 - acc: 0.9920 - val_loss: 0.3049 - val_acc: 0.9291
# Epoch 00064: early stopping

# %% [markdown]
# **绘制acc 和loss**

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
model2.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
scores = model2.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model2.metrics_names[1], scores[1]*100))

# confusion matrix
Y_pred=model2.predict_classes(X_test)
print(Y_pred.shape)
# Y_pred=np.transpose([Y_pred])
# print(Y_pred.shape)
# Out:
# acc: 93.45%
# WARNING:tensorflow:From <ipython-input-13-2256ef933b4f>:9: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# (3434,)

# %%
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
# Out:
# | Confusion Matrix |
# --------------------
#
#  [[1286   75    2]
#  [  85 1211   30]
#  [   1   32  712]]
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1363
#            1       0.92      0.91      0.92      1326
#            2       0.96      0.96      0.96       745
#
#     accuracy                           0.93      3434
#    macro avg       0.94      0.94      0.94      3434
# weighted avg       0.93      0.93      0.93      3434
