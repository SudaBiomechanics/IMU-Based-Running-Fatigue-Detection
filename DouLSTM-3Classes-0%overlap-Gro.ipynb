# %% [markdown]
# # LSTM-3Classes-Acc

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-0%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-0%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (17174, 200, 9)
# (17174, 1)

# %%
#只取前三列Acc数据
X_train=X_train[:,:,3:6]#只取前三列Acc数据
print(X_train.shape)
print(Y_train.shape)
# Out:
# (17174, 200, 3)
# (17174, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (15456, 200, 3)
# (15456, 1)
# (1718, 200, 3)
# (1718, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
## Import Keras
from __future__ import print_function
import keras
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
from attention import Attention
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

# %% [markdown]
# **LSTM Model**

# %%
# Initiliazing the sequential model
model2 = Sequential()
# Configuring the parameters
model2.add(LSTM(128, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal'))
# Adding a dropout layer
model2.add(Dropout(0.5))
#model2.add(Attention(64))
# #model2.add(BatchNormalization())
model2.add(LSTM(64))
# # Adding a dropout layer
model2.add(Dropout(0.5))
# # Adding a dense output layer with sigmoid activation
model2.add(Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))

model2.summary()
#-------------------
# Compiling the model
model2.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])#

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_loss', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.25,
    patience=8,#
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list =[mc,es,rp]
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200, 128)          67584
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 128)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 195
# =================================================================
# Total params: 117,187
# Trainable params: 117,187
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
#model2.load_weights("M2-weights-improvement-23-0.70.hdf5")
history=model2.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          validation_data=None,
          shuffle=True,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 13910 samples, validate on 1546 samples
# Epoch 1/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.1290 - acc: 0.3926WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.39327, saving model to M2-weights-improvement-01-0.39.hdf5
# 13910/13910 [==============================] - 155s 11ms/sample - loss: 1.1290 - acc: 0.3926 - val_loss: 1.1008 - val_acc: 0.3933
# Epoch 2/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0930 - acc: 0.4029
# Epoch 00002: val_acc improved from 0.39327 to 0.43144, saving model to M2-weights-improvement-02-0.43.hdf5
# 13910/13910 [==============================] - 143s 10ms/sample - loss: 1.0930 - acc: 0.4029 - val_loss: 1.0574 - val_acc: 0.4314
# Epoch 3/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0664 - acc: 0.4202
# Epoch 00003: val_acc improved from 0.43144 to 0.43208, saving model to M2-weights-improvement-03-0.43.hdf5
# 13910/13910 [==============================] - 142s 10ms/sample - loss: 1.0664 - acc: 0.4202 - val_loss: 1.0545 - val_acc: 0.4321
# Epoch 4/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0534 - acc: 0.4275
# Epoch 00004: val_acc improved from 0.43208 to 0.46572, saving model to M2-weights-improvement-04-0.47.hdf5
# 13910/13910 [==============================] - 149s 11ms/sample - loss: 1.0534 - acc: 0.4275 - val_loss: 1.0226 - val_acc: 0.4657
# Epoch 5/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0432 - acc: 0.4330
# Epoch 00005: val_acc did not improve from 0.46572
# 13910/13910 [==============================] - 150s 11ms/sample - loss: 1.0432 - acc: 0.4330 - val_loss: 1.0573 - val_acc: 0.4166
# Epoch 6/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0474 - acc: 0.4283
# Epoch 00006: val_acc did not improve from 0.46572
# 13910/13910 [==============================] - 145s 10ms/sample - loss: 1.0474 - acc: 0.4283 - val_loss: 1.0469 - val_acc: 0.4146
# Epoch 7/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0311 - acc: 0.4408
# Epoch 00007: val_acc improved from 0.46572 to 0.49159, saving model to M2-weights-improvement-07-0.49.hdf5
# 13910/13910 [==============================] - 141s 10ms/sample - loss: 1.0311 - acc: 0.4408 - val_loss: 0.9816 - val_acc: 0.4916
# Epoch 8/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0507 - acc: 0.4197
# Epoch 00008: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 139s 10ms/sample - loss: 1.0507 - acc: 0.4197 - val_loss: 1.0665 - val_acc: 0.4010
# Epoch 9/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0719 - acc: 0.4040
# Epoch 00009: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 138s 10ms/sample - loss: 1.0719 - acc: 0.4040 - val_loss: 1.0582 - val_acc: 0.4191
# Epoch 10/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0499 - acc: 0.4130
# Epoch 00010: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 1.0499 - acc: 0.4130 - val_loss: 1.0274 - val_acc: 0.4204
# Epoch 11/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0341 - acc: 0.4303
# Epoch 00011: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 1.0341 - acc: 0.4303 - val_loss: 0.9965 - val_acc: 0.4573
# Epoch 12/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0166 - acc: 0.4485
# Epoch 00012: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 1.0166 - acc: 0.4485 - val_loss: 0.9751 - val_acc: 0.4877
# Epoch 13/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0150 - acc: 0.4497
# Epoch 00013: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 138s 10ms/sample - loss: 1.0150 - acc: 0.4497 - val_loss: 0.9905 - val_acc: 0.4690
# Epoch 14/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0130 - acc: 0.4472
# Epoch 00014: val_acc did not improve from 0.49159
# 13910/13910 [==============================] - 135s 10ms/sample - loss: 1.0130 - acc: 0.4472 - val_loss: 0.9745 - val_acc: 0.4897
# Epoch 15/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9900 - acc: 0.4701
# Epoch 00015: val_acc improved from 0.49159 to 0.51423, saving model to M2-weights-improvement-15-0.51.hdf5
# 13910/13910 [==============================] - 136s 10ms/sample - loss: 0.9900 - acc: 0.4701 - val_loss: 0.9589 - val_acc: 0.5142
# Epoch 16/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9996 - acc: 0.4661
# Epoch 00016: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 134s 10ms/sample - loss: 0.9996 - acc: 0.4661 - val_loss: 0.9548 - val_acc: 0.5084
# Epoch 17/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9838 - acc: 0.4777
# Epoch 00017: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 141s 10ms/sample - loss: 0.9838 - acc: 0.4777 - val_loss: 0.9798 - val_acc: 0.4825
# Epoch 18/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9878 - acc: 0.4746
# Epoch 00018: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.9878 - acc: 0.4746 - val_loss: 0.9532 - val_acc: 0.4903
# Epoch 19/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9754 - acc: 0.4850
# Epoch 00019: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.9754 - acc: 0.4850 - val_loss: 0.9493 - val_acc: 0.5039
# Epoch 20/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9778 - acc: 0.4837
# Epoch 00020: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.9778 - acc: 0.4837 - val_loss: 0.9834 - val_acc: 0.4664
# Epoch 21/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0277 - acc: 0.4362
# Epoch 00021: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 134s 10ms/sample - loss: 1.0277 - acc: 0.4362 - val_loss: 1.0303 - val_acc: 0.4547
# Epoch 22/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0483 - acc: 0.4223
# Epoch 00022: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 134s 10ms/sample - loss: 1.0483 - acc: 0.4223 - val_loss: 1.0160 - val_acc: 0.4767
# Epoch 23/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0358 - acc: 0.4462
# Epoch 00023: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 135s 10ms/sample - loss: 1.0358 - acc: 0.4462 - val_loss: 1.0108 - val_acc: 0.4690
# Epoch 24/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0196 - acc: 0.4428
# Epoch 00024: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 135s 10ms/sample - loss: 1.0196 - acc: 0.4428 - val_loss: 1.0676 - val_acc: 0.3978
# Epoch 25/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0127 - acc: 0.4523
# Epoch 00025: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 136s 10ms/sample - loss: 1.0127 - acc: 0.4523 - val_loss: 1.0052 - val_acc: 0.4709
# Epoch 26/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9728 - acc: 0.4865
# Epoch 00026: val_acc did not improve from 0.51423
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.9728 - acc: 0.4865 - val_loss: 0.9656 - val_acc: 0.4838
# Epoch 27/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9446 - acc: 0.5037
# Epoch 00027: val_acc improved from 0.51423 to 0.52911, saving model to M2-weights-improvement-27-0.53.hdf5
# 13910/13910 [==============================] - 136s 10ms/sample - loss: 0.9446 - acc: 0.5037 - val_loss: 0.9075 - val_acc: 0.5291
# Epoch 28/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9179 - acc: 0.5207
# Epoch 00028: val_acc did not improve from 0.52911
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.9179 - acc: 0.5207 - val_loss: 0.9538 - val_acc: 0.5013
# Epoch 29/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9238 - acc: 0.5183
# Epoch 00029: val_acc did not improve from 0.52911
# 13910/13910 [==============================] - 136s 10ms/sample - loss: 0.9238 - acc: 0.5183 - val_loss: 0.9106 - val_acc: 0.5272
# Epoch 30/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9253 - acc: 0.5236
# Epoch 00030: val_acc improved from 0.52911 to 0.53622, saving model to M2-weights-improvement-30-0.54.hdf5
# 13910/13910 [==============================] - 143s 10ms/sample - loss: 0.9253 - acc: 0.5236 - val_loss: 0.9105 - val_acc: 0.5362
# Epoch 31/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9176 - acc: 0.5295
# Epoch 00031: val_acc improved from 0.53622 to 0.53816, saving model to M2-weights-improvement-31-0.54.hdf5
# 13910/13910 [==============================] - 138s 10ms/sample - loss: 0.9176 - acc: 0.5295 - val_loss: 0.9199 - val_acc: 0.5382
# Epoch 32/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9095 - acc: 0.5403
# Epoch 00032: val_acc improved from 0.53816 to 0.55757, saving model to M2-weights-improvement-32-0.56.hdf5
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.9095 - acc: 0.5403 - val_loss: 0.8846 - val_acc: 0.5576
# Epoch 33/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8892 - acc: 0.5554
# Epoch 00033: val_acc did not improve from 0.55757
# 13910/13910 [==============================] - 138s 10ms/sample - loss: 0.8892 - acc: 0.5554 - val_loss: 0.9009 - val_acc: 0.5414
# Epoch 34/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8957 - acc: 0.5503
# Epoch 00034: val_acc improved from 0.55757 to 0.56339, saving model to M2-weights-improvement-34-0.56.hdf5
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.8957 - acc: 0.5503 - val_loss: 0.8680 - val_acc: 0.5634
# Epoch 35/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8639 - acc: 0.5688
# Epoch 00035: val_acc improved from 0.56339 to 0.57050, saving model to M2-weights-improvement-35-0.57.hdf5
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.8639 - acc: 0.5688 - val_loss: 0.8509 - val_acc: 0.5705
# Epoch 36/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8601 - acc: 0.5728
# Epoch 00036: val_acc improved from 0.57050 to 0.59250, saving model to M2-weights-improvement-36-0.59.hdf5
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.8601 - acc: 0.5728 - val_loss: 0.8414 - val_acc: 0.5925
# Epoch 37/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8390 - acc: 0.5919
# Epoch 00037: val_acc did not improve from 0.59250
# 13910/13910 [==============================] - 126s 9ms/sample - loss: 0.8390 - acc: 0.5919 - val_loss: 0.8964 - val_acc: 0.5614
# Epoch 38/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8393 - acc: 0.5996
# Epoch 00038: val_acc improved from 0.59250 to 0.59897, saving model to M2-weights-improvement-38-0.60.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.8393 - acc: 0.5996 - val_loss: 0.8314 - val_acc: 0.5990
# Epoch 39/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8170 - acc: 0.6086
# Epoch 00039: val_acc did not improve from 0.59897
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.8170 - acc: 0.6086 - val_loss: 0.8251 - val_acc: 0.5938
# Epoch 40/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8004 - acc: 0.6197
# Epoch 00040: val_acc improved from 0.59897 to 0.64166, saving model to M2-weights-improvement-40-0.64.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.8004 - acc: 0.6197 - val_loss: 0.7891 - val_acc: 0.6417
# Epoch 41/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7910 - acc: 0.6291
# Epoch 00041: val_acc did not improve from 0.64166
# 13910/13910 [==============================] - 104s 8ms/sample - loss: 0.7910 - acc: 0.6291 - val_loss: 0.7914 - val_acc: 0.6268
# Epoch 42/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7670 - acc: 0.6548
# Epoch 00042: val_acc did not improve from 0.64166
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.7670 - acc: 0.6548 - val_loss: 0.8759 - val_acc: 0.6113
# Epoch 43/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7539 - acc: 0.6633
# Epoch 00043: val_acc did not improve from 0.64166
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.7539 - acc: 0.6633 - val_loss: 0.8954 - val_acc: 0.6229
# Epoch 44/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7352 - acc: 0.6811
# Epoch 00044: val_acc improved from 0.64166 to 0.68047, saving model to M2-weights-improvement-44-0.68.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.7352 - acc: 0.6811 - val_loss: 0.7272 - val_acc: 0.6805
# Epoch 45/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7214 - acc: 0.6854
# Epoch 00045: val_acc improved from 0.68047 to 0.69728, saving model to M2-weights-improvement-45-0.70.hdf5
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.7214 - acc: 0.6854 - val_loss: 0.7084 - val_acc: 0.6973
# Epoch 46/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7025 - acc: 0.6953
# Epoch 00046: val_acc improved from 0.69728 to 0.69858, saving model to M2-weights-improvement-46-0.70.hdf5
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.7025 - acc: 0.6953 - val_loss: 0.6923 - val_acc: 0.6986
# Epoch 47/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6918 - acc: 0.7065
# Epoch 00047: val_acc did not improve from 0.69858
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.6918 - acc: 0.7065 - val_loss: 0.7826 - val_acc: 0.6527
# Epoch 48/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6809 - acc: 0.7159
# Epoch 00048: val_acc improved from 0.69858 to 0.70505, saving model to M2-weights-improvement-48-0.71.hdf5
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.6809 - acc: 0.7159 - val_loss: 0.7010 - val_acc: 0.7050
# Epoch 49/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6657 - acc: 0.7260
# Epoch 00049: val_acc did not improve from 0.70505
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.6657 - acc: 0.7260 - val_loss: 0.7043 - val_acc: 0.7031
# Epoch 50/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6492 - acc: 0.7308
# Epoch 00050: val_acc did not improve from 0.70505
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.6492 - acc: 0.7308 - val_loss: 0.6957 - val_acc: 0.6986
# Epoch 51/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6426 - acc: 0.7385
# Epoch 00051: val_acc improved from 0.70505 to 0.71669, saving model to M2-weights-improvement-51-0.72.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.6426 - acc: 0.7385 - val_loss: 0.6723 - val_acc: 0.7167
# Epoch 52/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6319 - acc: 0.7444
# Epoch 00052: val_acc did not improve from 0.71669
# 13910/13910 [==============================] - 110s 8ms/sample - loss: 0.6319 - acc: 0.7444 - val_loss: 0.6852 - val_acc: 0.7031
# Epoch 53/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6145 - acc: 0.7521
# Epoch 00053: val_acc did not improve from 0.71669
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.6145 - acc: 0.7521 - val_loss: 0.7090 - val_acc: 0.7063
# Epoch 54/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6042 - acc: 0.7610
# Epoch 00054: val_acc did not improve from 0.71669
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.6042 - acc: 0.7610 - val_loss: 0.7620 - val_acc: 0.7122
# Epoch 55/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5957 - acc: 0.7620
# Epoch 00055: val_acc improved from 0.71669 to 0.74256, saving model to M2-weights-improvement-55-0.74.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.5957 - acc: 0.7620 - val_loss: 0.6458 - val_acc: 0.7426
# Epoch 56/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5915 - acc: 0.7628
# Epoch 00056: val_acc did not improve from 0.74256
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.5915 - acc: 0.7628 - val_loss: 0.6235 - val_acc: 0.7413
# Epoch 57/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5611 - acc: 0.7778
# Epoch 00057: val_acc did not improve from 0.74256
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.5611 - acc: 0.7778 - val_loss: 0.7039 - val_acc: 0.7147
# Epoch 58/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5735 - acc: 0.7729
# Epoch 00058: val_acc did not improve from 0.74256
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.5735 - acc: 0.7729 - val_loss: 0.6397 - val_acc: 0.7419
# Epoch 59/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5500 - acc: 0.7858
# Epoch 00059: val_acc did not improve from 0.74256
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.5500 - acc: 0.7858 - val_loss: 0.6747 - val_acc: 0.7335
# Epoch 60/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5513 - acc: 0.7860
# Epoch 00060: val_acc improved from 0.74256 to 0.76520, saving model to M2-weights-improvement-60-0.77.hdf5
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.5513 - acc: 0.7860 - val_loss: 0.6194 - val_acc: 0.7652
# Epoch 61/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5283 - acc: 0.7969
# Epoch 00061: val_acc did not improve from 0.76520
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.5283 - acc: 0.7969 - val_loss: 0.6461 - val_acc: 0.7367
# Epoch 62/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5145 - acc: 0.8050
# Epoch 00062: val_acc did not improve from 0.76520
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.5145 - acc: 0.8050 - val_loss: 0.6132 - val_acc: 0.7626
# Epoch 63/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5053 - acc: 0.8059
# Epoch 00063: val_acc did not improve from 0.76520
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.5053 - acc: 0.8059 - val_loss: 0.6631 - val_acc: 0.7490
# Epoch 64/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5159 - acc: 0.8059
# Epoch 00064: val_acc improved from 0.76520 to 0.78202, saving model to M2-weights-improvement-64-0.78.hdf5
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.5159 - acc: 0.8059 - val_loss: 0.5709 - val_acc: 0.7820
# Epoch 65/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4989 - acc: 0.8063
# Epoch 00065: val_acc did not improve from 0.78202
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.4989 - acc: 0.8063 - val_loss: 0.5741 - val_acc: 0.7658
# Epoch 66/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4865 - acc: 0.8222
# Epoch 00066: val_acc improved from 0.78202 to 0.78525, saving model to M2-weights-improvement-66-0.79.hdf5
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4865 - acc: 0.8222 - val_loss: 0.5972 - val_acc: 0.7853
# Epoch 67/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4744 - acc: 0.8214
# Epoch 00067: val_acc did not improve from 0.78525
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4744 - acc: 0.8214 - val_loss: 0.5714 - val_acc: 0.7678
# Epoch 68/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4736 - acc: 0.8226
# Epoch 00068: val_acc did not improve from 0.78525
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4736 - acc: 0.8226 - val_loss: 0.7304 - val_acc: 0.7212
# Epoch 69/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4698 - acc: 0.8253
# Epoch 00069: val_acc improved from 0.78525 to 0.79690, saving model to M2-weights-improvement-69-0.80.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4698 - acc: 0.8253 - val_loss: 0.5767 - val_acc: 0.7969
# Epoch 70/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4597 - acc: 0.8281
# Epoch 00070: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4597 - acc: 0.8281 - val_loss: 0.5566 - val_acc: 0.7840
# Epoch 71/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4489 - acc: 0.8349
# Epoch 00071: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4489 - acc: 0.8349 - val_loss: 0.5582 - val_acc: 0.7878
# Epoch 72/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4477 - acc: 0.8318
# Epoch 00072: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4477 - acc: 0.8318 - val_loss: 0.5494 - val_acc: 0.7930
# Epoch 73/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4361 - acc: 0.8371
# Epoch 00073: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4361 - acc: 0.8371 - val_loss: 0.6804 - val_acc: 0.7633
# Epoch 74/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4337 - acc: 0.8409
# Epoch 00074: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4337 - acc: 0.8409 - val_loss: 0.5807 - val_acc: 0.7930
# Epoch 75/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4238 - acc: 0.8449
# Epoch 00075: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4238 - acc: 0.8449 - val_loss: 0.5866 - val_acc: 0.7827
# Epoch 76/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4155 - acc: 0.8492
# Epoch 00076: val_acc did not improve from 0.79690
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4155 - acc: 0.8492 - val_loss: 0.5440 - val_acc: 0.7904
# Epoch 77/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4139 - acc: 0.8513
# Epoch 00077: val_acc improved from 0.79690 to 0.80724, saving model to M2-weights-improvement-77-0.81.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.4139 - acc: 0.8513 - val_loss: 0.5194 - val_acc: 0.8072
# Epoch 78/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3997 - acc: 0.8567
# Epoch 00078: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.3997 - acc: 0.8567 - val_loss: 0.5474 - val_acc: 0.7988
# Epoch 79/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3970 - acc: 0.8572
# Epoch 00079: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.3970 - acc: 0.8572 - val_loss: 0.5631 - val_acc: 0.8040
# Epoch 80/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3944 - acc: 0.8574
# Epoch 00080: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.3944 - acc: 0.8574 - val_loss: 0.5530 - val_acc: 0.8014
# Epoch 81/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3885 - acc: 0.8602
# Epoch 00081: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3885 - acc: 0.8602 - val_loss: 0.5532 - val_acc: 0.8034
# Epoch 82/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3870 - acc: 0.8636
# Epoch 00082: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.3870 - acc: 0.8636 - val_loss: 0.6123 - val_acc: 0.7658
# Epoch 83/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3681 - acc: 0.8697
# Epoch 00083: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3681 - acc: 0.8697 - val_loss: 0.5753 - val_acc: 0.8027
# Epoch 84/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3693 - acc: 0.8699
# Epoch 00084: val_acc did not improve from 0.80724
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.3693 - acc: 0.8699 - val_loss: 0.5433 - val_acc: 0.8047
# Epoch 85/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3675 - acc: 0.8712
# Epoch 00085: val_acc did not improve from 0.80724
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3675 - acc: 0.8712 - val_loss: 0.5410 - val_acc: 0.7943
# Epoch 86/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3139 - acc: 0.8937
# Epoch 00086: val_acc improved from 0.80724 to 0.83700, saving model to M2-weights-improvement-86-0.84.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3139 - acc: 0.8937 - val_loss: 0.4635 - val_acc: 0.8370
# Epoch 87/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2797 - acc: 0.9095
# Epoch 00087: val_acc improved from 0.83700 to 0.84153, saving model to M2-weights-improvement-87-0.84.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2797 - acc: 0.9095 - val_loss: 0.4735 - val_acc: 0.8415
# Epoch 88/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2656 - acc: 0.9155
# Epoch 00088: val_acc did not improve from 0.84153
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2656 - acc: 0.9155 - val_loss: 0.4885 - val_acc: 0.8364
# Epoch 89/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2655 - acc: 0.9159
# Epoch 00089: val_acc improved from 0.84153 to 0.84541, saving model to M2-weights-improvement-89-0.85.hdf5
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2655 - acc: 0.9159 - val_loss: 0.4790 - val_acc: 0.8454
# Epoch 90/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2554 - acc: 0.9208
# Epoch 00090: val_acc did not improve from 0.84541
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2554 - acc: 0.9208 - val_loss: 0.5082 - val_acc: 0.8305
# Epoch 91/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2563 - acc: 0.9190
# Epoch 00091: val_acc did not improve from 0.84541
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2563 - acc: 0.9190 - val_loss: 0.4895 - val_acc: 0.8376
# Epoch 92/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2475 - acc: 0.9216
# Epoch 00092: val_acc did not improve from 0.84541
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2475 - acc: 0.9216 - val_loss: 0.5065 - val_acc: 0.8415
# Epoch 93/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2422 - acc: 0.9254
# Epoch 00093: val_acc did not improve from 0.84541
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2422 - acc: 0.9254 - val_loss: 0.4922 - val_acc: 0.8415
# Epoch 94/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2375 - acc: 0.9298
# Epoch 00094: val_acc did not improve from 0.84541
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2375 - acc: 0.9298 - val_loss: 0.4963 - val_acc: 0.8396
# Epoch 95/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2227 - acc: 0.9336
# Epoch 00095: val_acc improved from 0.84541 to 0.84605, saving model to M2-weights-improvement-95-0.85.hdf5
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.2227 - acc: 0.9336 - val_loss: 0.5043 - val_acc: 0.8461
# Epoch 96/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2157 - acc: 0.9387
# Epoch 00096: val_acc improved from 0.84605 to 0.84735, saving model to M2-weights-improvement-96-0.85.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2157 - acc: 0.9387 - val_loss: 0.5052 - val_acc: 0.8473
# Epoch 97/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2170 - acc: 0.9348
# Epoch 00097: val_acc did not improve from 0.84735
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2170 - acc: 0.9348 - val_loss: 0.5164 - val_acc: 0.8441
# Epoch 98/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2167 - acc: 0.9370
# Epoch 00098: val_acc did not improve from 0.84735
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2167 - acc: 0.9370 - val_loss: 0.5138 - val_acc: 0.8415
# Epoch 99/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2140 - acc: 0.9395
# Epoch 00099: val_acc did not improve from 0.84735
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2140 - acc: 0.9395 - val_loss: 0.5090 - val_acc: 0.8467
# Epoch 100/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2096 - acc: 0.9398
# Epoch 00100: val_acc improved from 0.84735 to 0.84799, saving model to M2-weights-improvement-100-0.85.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2096 - acc: 0.9398 - val_loss: 0.5148 - val_acc: 0.8480
# Epoch 00100: early stopping

# %% [markdown]
# **绘制acc 和loss**

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
model2.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
scores = model2.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model2.metrics_names[1], scores[1]*100))

# confusion matrix
Y_pred=model2.predict_classes(X_test)
print(Y_pred.shape)
# Y_pred=np.transpose([Y_pred])
# print(Y_pred.shape)
# Out:
# acc: 87.19%
# WARNING:tensorflow:From <ipython-input-13-2256ef933b4f>:9: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# (1718,)

# %%
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
# Out:
# | Confusion Matrix |
# --------------------
#
#  [[624  63   2]
#  [ 64 555  34]
#  [  5  52 319]]
# | Classifiction Report |
# -------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       689
#            1       0.83      0.85      0.84       653
#            2       0.90      0.85      0.87       376
#
#     accuracy                           0.87      1718
#    macro avg       0.88      0.87      0.87      1718
# weighted avg       0.87      0.87      0.87      1718

# %%
from keras import backend as K
K.clear_session()
