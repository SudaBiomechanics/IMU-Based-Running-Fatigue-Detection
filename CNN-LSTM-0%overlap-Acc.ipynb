# %% [markdown]
# # CNN-LSTM自己

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-0%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-0%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (17174, 200, 9)
# (17174, 1)

# %%
#只取前列数据
X_train=X_train[:,:,0:3]#只取前
print(X_train.shape)
print(Y_train.shape)
# Out:
# (17174, 200, 3)
# (17174, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (15456, 200, 3)
# (15456, 1)
# (1718, 200, 3)
# (1718, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Import Keras
from __future__ import print_function
import keras
from keras import regularizers,Input
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax,concatenate
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
from keras.models import Model
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

print(timesteps,input_dim,len(X_train))
print(n_classes)
# Out:
# 200 3 15456
# 3

# %% [markdown]
# **LSTM Model**

# %%
def get_model():
    inp=Input(shape=(200,3))

    #CNN model
    reshape=Reshape((200,3,1))(inp)
    conv1=Conv2D(32,(18,1),activation='relu',strides=(2,1),padding='SAME',input_shape=(200,3,1))(reshape)
    maxp1=MaxPooling2D(pool_size=(2, 1))(conv1)
    conv2=Conv2D(64, (9, 1), activation='relu',padding='SAME')(maxp1)
    conv3=Conv2D(128, (3, 1), activation='relu',padding='SAME')(conv2)
    maxp3=MaxPooling2D(pool_size=(2, 1))(conv3)
    conv4=Conv2D(128, (1, 3), activation='relu', padding='VALID')(maxp3)
    cnn_out=Flatten()(conv4)


    #LSTM model
    lstm1=LSTM(64, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal')(inp)
    # Adding a dropout layer
    #model2.add(Dropout(0.25))
    batch1=BatchNormalization()(lstm1)
    lstm2=LSTM(64)(batch1)
    # Adding a dropout layer
    lstm_out=Dropout(0.5)(lstm2)

    m2=concatenate([cnn_out,lstm_out],axis=1)

    m2_out=Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                    activity_regularizer=regularizers.l1(0.01))(m2)
    model=Model(inputs=inp,outputs=m2_out)
    model.summary()
    return model

# %%
#-------------------
# Compiling the model
model=get_model()
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_acc', patience=16, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.25,
    patience=10,#多少epoch，如果monitor内容没有效果就earlystop
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list = [mc,es,rp]
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 3)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 3, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 3, 32)   608         reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 3, 32)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 3, 64)    18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 3, 128)   24704       conv2d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 200, 64)      17408       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 3, 128)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 64)      256         lstm[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 1, 128)   49280       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3200)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3264)         0           flatten[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            9795        concatenate[0][0]
# ==================================================================================================
# Total params: 153,571
# Trainable params: 153,443
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# Training the model
#model.load_weights("M-weights-improvement-19-0.93.hdf5")
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 13910 samples, validate on 1546 samples
# Epoch 1/200
# 13910/13910 [==============================] - ETA: 0s - loss: 3.9580 - acc: 0.4145WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.43273, saving model to M2-weights-improvement-01-0.43.hdf5
# 13910/13910 [==============================] - 101s 7ms/sample - loss: 3.9580 - acc: 0.4145 - val_loss: 1.0707 - val_acc: 0.4327
# Epoch 2/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0201 - acc: 0.4940
# Epoch 00002: val_acc improved from 0.43273 to 0.51940, saving model to M2-weights-improvement-02-0.52.hdf5
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 1.0201 - acc: 0.4940 - val_loss: 0.9634 - val_acc: 0.5194
# Epoch 3/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8942 - acc: 0.5771
# Epoch 00003: val_acc did not improve from 0.51940
# 13910/13910 [==============================] - 99s 7ms/sample - loss: 0.8942 - acc: 0.5771 - val_loss: 1.0230 - val_acc: 0.4832
# Epoch 4/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7915 - acc: 0.6332
# Epoch 00004: val_acc improved from 0.51940 to 0.68305, saving model to M2-weights-improvement-04-0.68.hdf5
# 13910/13910 [==============================] - 110s 8ms/sample - loss: 0.7915 - acc: 0.6332 - val_loss: 0.7111 - val_acc: 0.6831
# Epoch 5/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6978 - acc: 0.6961
# Epoch 00005: val_acc did not improve from 0.68305
# 13910/13910 [==============================] - 99s 7ms/sample - loss: 0.6978 - acc: 0.6961 - val_loss: 0.7761 - val_acc: 0.6527
# Epoch 6/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6353 - acc: 0.7231
# Epoch 00006: val_acc improved from 0.68305 to 0.75420, saving model to M2-weights-improvement-06-0.75.hdf5
# 13910/13910 [==============================] - 97s 7ms/sample - loss: 0.6353 - acc: 0.7231 - val_loss: 0.6107 - val_acc: 0.7542
# Epoch 7/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5811 - acc: 0.7473
# Epoch 00007: val_acc improved from 0.75420 to 0.77878, saving model to M2-weights-improvement-07-0.78.hdf5
# 13910/13910 [==============================] - 98s 7ms/sample - loss: 0.5811 - acc: 0.7473 - val_loss: 0.5572 - val_acc: 0.7788
# Epoch 8/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5333 - acc: 0.7782
# Epoch 00008: val_acc did not improve from 0.77878
# 13910/13910 [==============================] - 107s 8ms/sample - loss: 0.5333 - acc: 0.7782 - val_loss: 0.6585 - val_acc: 0.7290
# Epoch 9/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4887 - acc: 0.7950
# Epoch 00009: val_acc did not improve from 0.77878
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.4887 - acc: 0.7950 - val_loss: 0.6926 - val_acc: 0.7238
# Epoch 10/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4570 - acc: 0.8164
# Epoch 00010: val_acc improved from 0.77878 to 0.78590, saving model to M2-weights-improvement-10-0.79.hdf5
# 13910/13910 [==============================] - 101s 7ms/sample - loss: 0.4570 - acc: 0.8164 - val_loss: 0.5554 - val_acc: 0.7859
# Epoch 11/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4133 - acc: 0.8410
# Epoch 00011: val_acc improved from 0.78590 to 0.82018, saving model to M2-weights-improvement-11-0.82.hdf5
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.4133 - acc: 0.8410 - val_loss: 0.4703 - val_acc: 0.8202
# Epoch 12/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3914 - acc: 0.8555
# Epoch 00012: val_acc did not improve from 0.82018
# 13910/13910 [==============================] - 101s 7ms/sample - loss: 0.3914 - acc: 0.8555 - val_loss: 0.4989 - val_acc: 0.8092
# Epoch 13/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3533 - acc: 0.8740
# Epoch 00013: val_acc did not improve from 0.82018
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.3533 - acc: 0.8740 - val_loss: 0.5525 - val_acc: 0.7917
# Epoch 14/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3445 - acc: 0.8753
# Epoch 00014: val_acc improved from 0.82018 to 0.83959, saving model to M2-weights-improvement-14-0.84.hdf5
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0
200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0264 - acc: 0.9986
# Epoch 00058: val_acc did not improve from 0.86417
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.0264 - acc: 0.9986 - val_loss: 0.5376 - val_acc: 0.8603
# Epoch 59/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0262 - acc: 0.9987
# Epoch 00059: val_acc did not improve from 0.86417
# 13910/13910 [==============================] - 120s 9ms/sample - loss: 0.0262 - acc: 0.9987 - val_loss: 0.5092 - val_acc: 0.8577
# Epoch 60/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0253 - acc: 0.9991
# Epoch 00060: val_acc improved from 0.86417 to 0.86546, saving model to M2-weights-improvement-60-0.87.hdf5
# 13910/13910 [==============================] - 109s 8ms/sample - loss: 0.0253 - acc: 0.9991 - val_loss: 0.5185 - val_acc: 0.8655
# Epoch 61/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0238 - acc: 0.9991
# Epoch 00061: val_acc did not improve from 0.86546
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.0238 - acc: 0.9991 - val_loss: 0.5264 - val_acc: 0.8622
# Epoch 62/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0234 - acc: 0.9994
# Epoch 00062: val_acc did not improve from 0.86546
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.0234 - acc: 0.9994 - val_loss: 0.5700 - val_acc: 0.8648
# Epoch 63/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0253 - acc: 0.9983
# Epoch 00063: val_acc did not improve from 0.86546
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.0253 - acc: 0.9983 - val_loss: 0.5558 - val_acc: 0.8616
# Epoch 64/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0261 - acc: 0.9978
# Epoch 00064: val_acc improved from 0.86546 to 0.86675, saving model to M2-weights-improvement-64-0.87.hdf5
# 13910/13910 [==============================] - 110s 8ms/sample - loss: 0.0261 - acc: 0.9978 - val_loss: 0.5168 - val_acc: 0.8668
# Epoch 65/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0246 - acc: 0.9984
# Epoch 00065: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.0246 - acc: 0.9984 - val_loss: 0.5250 - val_acc: 0.8642
# Epoch 66/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0248 - acc: 0.9986
# Epoch 00066: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 112s 8ms/sample - loss: 0.0248 - acc: 0.9986 - val_loss: 0.5177 - val_acc: 0.8648
# Epoch 67/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0247 - acc: 0.9980
# Epoch 00067: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.0247 - acc: 0.9980 - val_loss: 0.5317 - val_acc: 0.8629
# Epoch 68/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0238 - acc: 0.9984
# Epoch 00068: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 110s 8ms/sample - loss: 0.0238 - acc: 0.9984 - val_loss: 0.5379 - val_acc: 0.8596
# Epoch 69/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0239 - acc: 0.9987
# Epoch 00069: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 109s 8ms/sample - loss: 0.0239 - acc: 0.9987 - val_loss: 0.5690 - val_acc: 0.8564
# Epoch 70/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0247 - acc: 0.9981
# Epoch 00070: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.0247 - acc: 0.9981 - val_loss: 0.5225 - val_acc: 0.8655
# Epoch 71/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0231 - acc: 0.9987
# Epoch 00071: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.0231 - acc: 0.9987 - val_loss: 0.5297 - val_acc: 0.8622
# Epoch 72/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0239 - acc: 0.9980
# Epoch 00072: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0239 - acc: 0.9980 - val_loss: 0.5339 - val_acc: 0.8661
# Epoch 73/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0223 - acc: 0.9983
# Epoch 00073: val_acc did not improve from 0.86675
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0223 - acc: 0.9983 - val_loss: 0.5940 - val_acc: 0.8655
# Epoch 74/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0245 - acc: 0.9976
# Epoch 00074: val_acc did not improve from 0.86675
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0245 - acc: 0.9976 - val_loss: 0.5253 - val_acc: 0.8642
# Epoch 75/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0194 - acc: 0.9999
# Epoch 00075: val_acc improved from 0.86675 to 0.86934, saving model to M2-weights-improvement-75-0.87.hdf5
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.0194 - acc: 0.9999 - val_loss: 0.5486 - val_acc: 0.8693
# Epoch 76/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0188 - acc: 0.9999
# Epoch 00076: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 108s 8ms/sample - loss: 0.0188 - acc: 0.9999 - val_loss: 0.5651 - val_acc: 0.8616
# Epoch 77/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0185 - acc: 0.9999
# Epoch 00077: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.0185 - acc: 0.9999 - val_loss: 0.5582 - val_acc: 0.8648
# Epoch 78/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0182 - acc: 0.9999
# Epoch 00078: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.0182 - acc: 0.9999 - val_loss: 0.5543 - val_acc: 0.8635
# Epoch 79/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0179 - acc: 0.9999
# Epoch 00079: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0179 - acc: 0.9999 - val_loss: 0.5535 - val_acc: 0.8687
# Epoch 80/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0177 - acc: 0.9999
# Epoch 00080: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0177 - acc: 0.9999 - val_loss: 0.5627 - val_acc: 0.8622
# Epoch 81/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0176 - acc: 0.9999
# Epoch 00081: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0176 - acc: 0.9999 - val_loss: 0.5616 - val_acc: 0.8609
# Epoch 82/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0174 - acc: 0.9998
# Epoch 00082: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0174 - acc: 0.9998 - val_loss: 0.5719 - val_acc: 0.8680
# Epoch 83/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0173 - acc: 0.9998
# Epoch 00083: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0173 - acc: 0.9998 - val_loss: 0.5613 - val_acc: 0.8616
# Epoch 84/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0170 - acc: 0.9999
# Epoch 00084: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.0170 - acc: 0.9999 - val_loss: 0.5679 - val_acc: 0.8616
# Epoch 85/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0169 - acc: 0.9999
# Epoch 00085: val_acc did not improve from 0.86934
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.0169 - acc: 0.9999 - val_loss: 0.5717 - val_acc: 0.8577
# Epoch 86/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0166 - acc: 0.9999
# Epoch 00086: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 108s 8ms/sample - loss: 0.0166 - acc: 0.9999 - val_loss: 0.5694 - val_acc: 0.8609
# Epoch 87/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0166 - acc: 0.9999
# Epoch 00087: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 108s 8ms/sample - loss: 0.0166 - acc: 0.9999 - val_loss: 0.5686 - val_acc: 0.8616
# Epoch 88/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0165 - acc: 0.9999
# Epoch 00088: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.0165 - acc: 0.9999 - val_loss: 0.5686 - val_acc: 0.8622
# Epoch 89/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0164 - acc: 0.9999
# Epoch 00089: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 108s 8ms/sample - loss: 0.0164 - acc: 0.9999 - val_loss: 0.5646 - val_acc: 0.8622
# Epoch 90/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0164 - acc: 0.9998
# Epoch 00090: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 108s 8ms/sample - loss: 0.0164 - acc: 0.9998 - val_loss: 0.5643 - val_acc: 0.8616
# Epoch 91/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0163 - acc: 0.9999
# Epoch 00091: val_acc did not improve from 0.86934
# 13910/13910 [==============================] - 109s 8ms/sample - loss: 0.0163 - acc: 0.9999 - val_loss: 0.5656 - val_acc: 0.8622
# Epoch 00091: early stopping

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')
plt.ylim([0.6,1])

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
scores = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# confusion matrix
Y_pred=model.predict_classes(X_test)
print(Y_pred.shape)
# Out:
# acc: 88.18%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-cc54c5cf9ee2> in <module>
#       7
#       8 # confusion matrix
# ----> 9 Y_pred=model.predict_classes(X_test)
#      10 print(Y_pred.shape)
#
# AttributeError: 'Functional' object has no attribute 'predict_classes'

# %%
from sklearn.metrics import confusion_matrix
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
