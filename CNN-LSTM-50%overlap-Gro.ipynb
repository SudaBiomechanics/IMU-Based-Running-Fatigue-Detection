# %% [markdown]
# # CNN-LSTM自己

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-50%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-50%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (34334, 200, 9)
# (34334, 1)

# %%
#只取前列数据
X_train=X_train[:,:,3:6]#只取前
print(X_train.shape)
print(Y_train.shape)
# Out:
# (34334, 200, 3)
# (34334, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (30900, 200, 3)
# (30900, 1)
# (3434, 200, 3)
# (3434, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Import Keras
from __future__ import print_function
import keras
from keras import regularizers,Input
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax,concatenate
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
from keras.models import Model
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

print(timesteps,input_dim,len(X_train))
print(n_classes)
# Out:
# 200 3 30900
# 3

# %% [markdown]
# **LSTM Model**

# %%
def get_model():
    inp=Input(shape=(200,3))

    #CNN model
    reshape=Reshape((200,3,1))(inp)
    conv1=Conv2D(32,(18,1),activation='relu',strides=(2,1),padding='SAME',input_shape=(200,3,1))(reshape)
    maxp1=MaxPooling2D(pool_size=(2, 1))(conv1)
    conv2=Conv2D(64, (9, 1), activation='relu',padding='SAME')(maxp1)
    conv3=Conv2D(128, (3, 1), activation='relu',padding='SAME')(conv2)
    maxp3=MaxPooling2D(pool_size=(2, 1))(conv3)
    conv4=Conv2D(128, (1, 3), activation='relu', padding='VALID')(maxp3)
    cnn_out=Flatten()(conv4)


    #LSTM model
    lstm1=LSTM(64, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal')(inp)
    # Adding a dropout layer
    #model2.add(Dropout(0.25))
    batch1=BatchNormalization()(lstm1)
    lstm2=LSTM(64)(batch1)
    # Adding a dropout layer
    lstm_out=Dropout(0.5)(lstm2)

    m2=concatenate([cnn_out,lstm_out],axis=1)

    m2_out=Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                    activity_regularizer=regularizers.l1(0.01))(m2)
    model=Model(inputs=inp,outputs=m2_out)
    model.summary()
    return model

# %%
#-------------------
# Compiling the model
model=get_model()
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_loss', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.25,
    patience=8,#多少epoch，如果monitor内容没有效果就earlystop
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list = [mc,es,rp]
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 3)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 3, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 3, 32)   608         reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 3, 32)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 3, 64)    18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 3, 128)   24704       conv2d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 200, 64)      17408       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 3, 128)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 64)      256         lstm[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 1, 128)   49280       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3200)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3264)         0           flatten[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            9795        concatenate[0][0]
# ==================================================================================================
# Total params: 153,571
# Trainable params: 153,443
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# Training the model
#model.load_weights("M-weights-improvement-19-0.93.hdf5")
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 27810 samples, validate on 3090 samples
# Epoch 1/200
# 27810/27810 [==============================] - ETA: 0s - loss: 1.0837 - acc: 0.4492WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.48188, saving model to M2-weights-improvement-01-0.48.hdf5
# 27810/27810 [==============================] - 217s 8ms/sample - loss: 1.0837 - acc: 0.4492 - val_loss: 1.0185 - val_acc: 0.4819
# Epoch 2/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.9473 - acc: 0.5417
# Epoch 00002: val_acc improved from 0.48188 to 0.62168, saving model to M2-weights-improvement-02-0.62.hdf5
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.9473 - acc: 0.5417 - val_loss: 0.8318 - val_acc: 0.6217
# Epoch 3/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.8204 - acc: 0.6273
# Epoch 00003: val_acc did not improve from 0.62168
# 27810/27810 [==============================] - 190s 7ms/sample - loss: 0.8204 - acc: 0.6273 - val_loss: 0.9090 - val_acc: 0.6000
# Epoch 4/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.7085 - acc: 0.6909
# Epoch 00004: val_acc improved from 0.62168 to 0.78900, saving model to M2-weights-improvement-04-0.79.hdf5
# 27810/27810 [==============================] - 196s 7ms/sample - loss: 0.7085 - acc: 0.6909 - val_loss: 0.5835 - val_acc: 0.7890
# Epoch 5/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.6126 - acc: 0.7466
# Epoch 00005: val_acc did not improve from 0.78900
# 27810/27810 [==============================] - 195s 7ms/sample - loss: 0.6126 - acc: 0.7466 - val_loss: 0.5572 - val_acc: 0.7764
# Epoch 6/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5462 - acc: 0.7821
# Epoch 00006: val_acc improved from 0.78900 to 0.83430, saving model to M2-weights-improvement-06-0.83.hdf5
# 27810/27810 [==============================] - 187s 7ms/sample - loss: 0.5462 - acc: 0.7821 - val_loss: 0.4577 - val_acc: 0.8343
# Epoch 7/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4923 - acc: 0.8102
# Epoch 00007: val_acc did not improve from 0.83430
# 27810/27810 [==============================] - 192s 7ms/sample - loss: 0.4923 - acc: 0.8102 - val_loss: 0.4678 - val_acc: 0.8285
# Epoch 8/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4431 - acc: 0.8341
# Epoch 00008: val_acc improved from 0.83430 to 0.87832, saving model to M2-weights-improvement-08-0.88.hdf5
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.4431 - acc: 0.8341 - val_loss: 0.3680 - val_acc: 0.8783
# Epoch 9/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4083 - acc: 0.8528
# Epoch 00009: val_acc did not improve from 0.87832
# 27810/27810 [==============================] - 214s 8ms/sample - loss: 0.4083 - acc: 0.8528 - val_loss: 0.4289 - val_acc: 0.8375
# Epoch 10/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3794 - acc: 0.8617
# Epoch 00010: val_acc did not improve from 0.87832
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.3794 - acc: 0.8617 - val_loss: 0.5597 - val_acc: 0.7893
# Epoch 11/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3460 - acc: 0.8762
# Epoch 00011: val_acc improved from 0.87832 to 0.88350, saving model to M2-weights-improvement-11-0.88.hdf5
# 27810/27810 [==============================] - 196s 7ms/sample - loss: 0.3460 - acc: 0.8762 - val_loss: 0.3416 - val_acc: 0.8835
# Epoch 12/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3272 - acc: 0.8844
# Epoch 00012: val_acc did not improve from 0.88350
# 27810/27810 [==============================] - 205s 7ms/sample - loss: 0.3272 - acc: 0.8844 - val_loss: 0.4379 - val_acc: 0.8337
# Epoch 13/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3087 - acc: 0.8937
# Epoch 00013: val_acc did not improve from 0.88350
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.3087 - acc: 0.8937 - val_loss: 0.4462 - val_acc: 0.8388
# Epoch 14/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2877 - acc: 0.9010
# Epoch 00014: val_acc improved from 0.88350 to 0.88900, saving model to M2-weights-improvement-14-0.89.hdf5
# 27810/27810 [==============================] - 194s 7ms/sample - loss: 0.2877 - acc: 0.9010 - val_loss: 0.3344 - val_acc: 0.8890
# Epoch 15/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2679 - acc: 0.9109
# Epoch 00015: val_acc improved from 0.88900 to 0.89353, saving model to M2-weights-improvement-15-0.89.hdf5
# 27810/27810 [==============================] - 195s 7ms/sample - loss: 0.2679 - acc: 0.9109 - val_loss: 0.3204 - val_acc: 0.8935
# Epoch 16/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2539 - acc: 0.9162
# Epoch 00016: val_acc improved from 0.89353 to 0.92104, saving model to M2-weights-improvement-16-0.92.hdf5
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.2539 - acc: 0.9162 - val_loss: 0.2448 - val_acc: 0.9210
# Epoch 17/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2419 - acc: 0.9199
# Epoch 00017: val_acc improved from 0.92104 to 0.92265, saving model to M2-weights-improvement-17-0.92.hdf5
# 27810/27810 [==============================] - 204s 7ms/sample - loss: 0.2419 - acc: 0.9199 - val_loss: 0.2453 - val_acc: 0.9227
# Epoch 18/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2270 - acc: 0.9268
# Epoch 00018: val_acc did not improve from 0.92265
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.2270 - acc: 0.9268 - val_loss: 0.3722 - val_acc: 0.8858
# Epoch 19/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2145 - acc: 0.9332
# Epoch 00019: val_acc improved from 0.92265 to 0.92751, saving model to M2-weights-improvement-19-0.93.hdf5
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.2145 - acc: 0.9332 - val_loss: 0.2363 - val_acc: 0.9275
# Epoch 20/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2051 - acc: 0.9366
# Epoch 00020: val_acc did not improve from 0.92751
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.2051 - acc: 0.9366 - val_loss: 0.3130 - val_acc: 0.8951
# Epoch 21/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1930 - acc: 0.9404
# Epoch 00021: val_acc did not improve from 0.92751
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1930 - acc: 0.9404 - val_loss: 0.2370 - val_acc: 0.9252
# Epoch 22/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1789 - acc: 0.9456
# Epoch 00022: val_acc improved from 0.92751 to 0.93689, saving model to M2-weights-improvement-22-0.94.hdf5
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.1789 - acc: 0.9456 - val_loss: 0.2112 - val_acc: 0.9369
# Epoch 23/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1715 - acc: 0.9481
# Epoch 00023: val_acc did not improve from 0.93689
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.1715 - acc: 0.9481 - val_loss: 0.2226 - val_acc: 0.9275
# Epoch 24/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1637 - acc: 0.9520
# Epoch 00024: val_acc improved from 0.93689 to 0.93786, saving model to M2-weights-improvement-24-0.94.hdf5
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1637 - acc: 0.9520 - val_loss: 0.2067 - val_acc: 0.9379
# Epoch 25/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1624 - acc: 0.9520
# Epoch 00025: val_acc improved from 0.93786 to 0.94595, saving model to M2-weights-improvement-25-0.95.hdf5
# 27810/27810 [==============================] - 205s 7ms/sample - loss: 0.1624 - acc: 0.9520 - val_loss: 0.1980 - val_acc: 0.9460
# Epoch 26/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1487 - acc: 0.9571
# Epoch 00026: val_acc did not improve from 0.94595
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.1487 - acc: 0.9571 - val_loss: 0.2379 - val_acc: 0.9204
# Epoch 27/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1417 - acc: 0.9600
# Epoch 00027: val_acc did not improve from 0.94595
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1417 - acc: 0.9600 - val_loss: 0.2134 - val_acc: 0.9359
# Epoch 28/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1382 - acc: 0.9626
# Epoch 00028: val_acc did not improve from 0.94595
# 27810/27810 [==============================] - 201s 7ms/sample - loss: 0.1382 - acc: 0.9626 - val_loss: 0.1986 - val_acc: 0.9398
# Epoch 29/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1322 - acc: 0.9633
# Epoch 00029: val_acc did not improve from 0.94595
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1322 - acc: 0.9633 - val_loss: 0.1993 - val_acc: 0.9440
# Epoch 30/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1253 - acc: 0.9662
# Epoch 00030: val_acc did not improve from 0.94595
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1253 - acc: 0.9662 - val_loss: 0.2033 - val_acc: 0.9421
# Epoch 31/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1229 - acc: 0.9670
# Epoch 00031: val_acc improved from 0.94595 to 0.94984, saving model to M2-weights-improvement-31-0.95.hdf5
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1229 - acc: 0.9670 - val_loss: 0.1793 - val_acc: 0.9498
# Epoch 32/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1125 - acc: 0.9715
# Epoch 00032: val_acc did not improve from 0.94984
# 27810/27810 [==============================] - 200s 7ms/sample - loss: 0.1125 - acc: 0.9715 - val_loss: 0.2065 - val_acc: 0.9395
# Epoch 33/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1113 - acc: 0.9713
# Epoch 00033: val_acc improved from 0.94984 to 0.95016, saving model to M2-weights-improvement-33-0.95.hdf5
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.1113 - acc: 0.9713 - val_loss: 0.1803 - val_acc: 0.9502
# Epoch 34/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1108 - acc: 0.9722
# Epoch 00034: val_acc improved from 0.95016 to 0.95243, saving model to M2-weights-improvement-34-0.95.hdf5
# 27810/27810 [==============================] - 205s 7ms/sample - loss: 0.1108 - acc: 0.9722 - val_loss: 0.1761 - val_acc: 0.9524
# Epoch 35/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1084 - acc: 0.9739
# Epoch 00035: val_acc improved from 0.95243 to 0.95275, saving model to M2-weights-improvement-35-0.95.hdf5
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.1084 - acc: 0.9739 - val_loss: 0.1795 - val_acc: 0.9528
# Epoch 36/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0942 - acc: 0.9775
# Epoch 00036: val_acc did not improve from 0.95275
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.0942 - acc: 0.9775 - val_loss: 0.2142 - val_acc: 0.9414
# Epoch 37/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0975 - acc: 0.9765
# Epoch 00037: val_acc did not improve from 0.95275
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0975 - acc: 0.9765 - val_loss: 0.1849 - val_acc: 0.9521
# Epoch 38/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1003 - acc: 0.9768
# Epoch 00038: val_acc improved from 0.95275 to 0.95437, saving model to M2-weights-improvement-38-0.95.hdf5
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.1003 - acc: 0.9768 - val_loss: 0.1708 - val_acc: 0.9544
# Epoch 39/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0880 - acc: 0.9807
# Epoch 00039: val_acc did not improve from 0.95437
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.0880 - acc: 0.9807 - val_loss: 0.1977 - val_acc: 0.9492
# Epoch 40/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0865 - acc: 0.9807
# Epoch 00040: val_acc did not improve from 0.95437
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.0865 - acc: 0.9807 - val_loss: 0.3432 - val_acc: 0.8997
# Epoch 41/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0834 - acc: 0.9828
# Epoch 00041: val_acc did not improve from 0.95437
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.0834 - acc: 0.9828 - val_loss: 0.2436 - val_acc: 0.9317
# Epoch 42/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0824 - acc: 0.9826
# Epoch 00042: val_acc improved from 0.95437 to 0.95534, saving model to M2-weights-improvement-42-0.96.hdf5
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0824 - acc: 0.9826 - val_loss: 0.1815 - val_acc: 0.9553
# Epoch 43/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0831 - acc: 0.9832
# Epoch 00043: val_acc did not improve from 0.95534
# 27810/27810 [==============================] - 204s 7ms/sample - loss: 0.0831 - acc: 0.9832 - val_loss: 0.1788 - val_acc: 0.9550
# Epoch 44/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0752 - acc: 0.9845
# Epoch 00044: val_acc improved from 0.95534 to 0.95793, saving model to M2-weights-improvement-44-0.96.hdf5
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0752 - acc: 0.9845 - val_loss: 0.1693 - val_acc: 0.9579
# Epoch 45/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0811 - acc: 0.9841
# Epoch 00045: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0811 - acc: 0.9841 - val_loss: 0.1670 - val_acc: 0.9573
# Epoch 46/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0727 - acc: 0.9850
# Epoch 00046: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0727 - acc: 0.9850 - val_loss: 0.1689 - val_acc: 0.9553
# Epoch 47/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0701 - acc: 0.9867
# Epoch 00047: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0701 - acc: 0.9867 - val_loss: 0.1718 - val_acc: 0.9566
# Epoch 48/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0693 - acc: 0.9864
# Epoch 00048: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0693 - acc: 0.9864 - val_loss: 0.2021 - val_acc: 0.9482
# Epoch 49/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0744 - acc: 0.9843
# Epoch 00049: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0744 - acc: 0.9843 - val_loss: 0.1695 - val_acc: 0.9557
# Epoch 50/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0634 - acc: 0.9882
# Epoch 00050: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 199s 7ms/sample - loss: 0.0634 - acc: 0.9882 - val_loss: 0.3807 - val_acc: 0.9129
# Epoch 51/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0658 - acc: 0.9874
# Epoch 00051: val_acc did not improve from 0.95793
# 27810/27810 [==============================] - 198s 7ms/sample - loss: 0.0658 - acc: 0.9874 - val_loss: 0.1906 - val_acc: 0.9511
# Epoch 52/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0628 - acc: 0.9885
# Epoch 00052: val_acc did not improve from 0.95793
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27810/27810 [==============================] - 205s 7ms/sample - loss: 0.0628 - acc: 0.9885 - val_loss: 0.1789 - val_acc: 0.9544
# Epoch 53/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0314 - acc: 0.9990
# Epoch 00053: val_acc improved from 0.95793 to 0.96246, saving model to M2-weights-improvement-53-0.96.hdf5
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0314 - acc: 0.9990 - val_loss: 0.1663 - val_acc: 0.9625
# Epoch 54/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0282 - acc: 0.9991
# Epoch 00054: val_acc did not improve from 0.96246
# 27810/27810 [==============================] - 204s 7ms/sample - loss: 0.0282 - acc: 0.9991 - val_loss: 0.1650 - val_acc: 0.9612
# Epoch 55/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0264 - acc: 0.9991
# Epoch 00055: val_acc improved from 0.96246 to 0.96278, saving model to M2-weights-improvement-55-0.96.hdf5
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0264 - acc: 0.9991 - val_loss: 0.1653 - val_acc: 0.9628
# Epoch 56/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0253 - acc: 0.9994
# Epoch 00056: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0253 - acc: 0.9994 - val_loss: 0.1618 - val_acc: 0.9621
# Epoch 57/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0246 - acc: 0.9995
# Epoch 00057: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0246 - acc: 0.9995 - val_loss: 0.1690 - val_acc: 0.9621
# Epoch 58/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0237 - acc: 0.9992
# Epoch 00058: val_acc improved from 0.96278 to 0.96343, saving model to M2-weights-improvement-58-0.96.hdf5
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0237 - acc: 0.9992 - val_loss: 0.1663 - val_acc: 0.9634
# Epoch 59/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0231 - acc: 0.9993
# Epoch 00059: val_acc improved from 0.96343 to 0.96375, saving model to M2-weights-improvement-59-0.96.hdf5
# 27810/27810 [==============================] - 202s 7ms/sample - loss: 0.0231 - acc: 0.9993 - val_loss: 0.1615 - val_acc: 0.9638
# Epoch 60/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0227 - acc: 0.9993
# Epoch 00060: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0227 - acc: 0.9993 - val_loss: 0.1659 - val_acc: 0.9605
# Epoch 61/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0221 - acc: 0.9992
# Epoch 00061: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 208s 7ms/sample - loss: 0.0221 - acc: 0.9992 - val_loss: 0.1849 - val_acc: 0.9540
# Epoch 62/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0219 - acc: 0.9994
# Epoch 00062: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0219 - acc: 0.9994 - val_loss: 0.1701 - val_acc: 0.9579
# Epoch 63/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0217 - acc: 0.9992
# Epoch 00063: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0217 - acc: 0.9992 - val_loss: 0.1605 - val_acc: 0.9634
# Epoch 64/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0211 - acc: 0.9992
# Epoch 00064: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0211 - acc: 0.9992 - val_loss: 0.1622 - val_acc: 0.9634
# Epoch 65/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0207 - acc: 0.9995
# Epoch 00065: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 203s 7ms/sample - loss: 0.0207 - acc: 0.9995 - val_loss: 0.1687 - val_acc: 0.9628
# Epoch 66/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0205 - acc: 0.9995
# Epoch 00066: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 187s 7ms/sample - loss: 0.0205 - acc: 0.9995 - val_loss: 0.1587 - val_acc: 0.9631
# Epoch 67/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0202 - acc: 0.9995
# Epoch 00067: val_acc did not improve from 0.96375
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 27810/27810 [==============================] - 145s 5ms/sample - loss: 0.0202 - acc: 0.9995 - val_loss: 0.1686 - val_acc: 0.9612
# Epoch 68/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0184 - acc: 0.9996
# Epoch 00068: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 146s 5ms/sample - loss: 0.0184 - acc: 0.9996 - val_loss: 0.1655 - val_acc: 0.9618
# Epoch 69/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0180 - acc: 0.9996
# Epoch 00069: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 145s 5ms/sample - loss: 0.0180 - acc: 0.9996 - val_loss: 0.1633 - val_acc: 0.9618
# Epoch 70/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0178 - acc: 0.9997
# Epoch 00070: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 147s 5ms/sample - loss: 0.0178 - acc: 0.9997 - val_loss: 0.1632 - val_acc: 0.9625
# Epoch 71/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0177 - acc: 0.9996
# Epoch 00071: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 157s 6ms/sample - loss: 0.0177 - acc: 0.9996 - val_loss: 0.1611 - val_acc: 0.9615
# Epoch 72/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0175 - acc: 0.9997
# Epoch 00072: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 147s 5ms/sample - loss: 0.0175 - acc: 0.9997 - val_loss: 0.1608 - val_acc: 0.9618
# Epoch 73/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0174 - acc: 0.9996
# Epoch 00073: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 147s 5ms/sample - loss: 0.0174 - acc: 0.9996 - val_loss: 0.1666 - val_acc: 0.9631
# Epoch 74/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0172 - acc: 0.9996
# Epoch 00074: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 145s 5ms/sample - loss: 0.0172 - acc: 0.9996 - val_loss: 0.1634 - val_acc: 0.9621
# Epoch 75/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0171 - acc: 0.9996
# Epoch 00075: val_acc did not improve from 0.96375
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 27810/27810 [==============================] - 147s 5ms/sample - loss: 0.0171 - acc: 0.9996 - val_loss: 0.1663 - val_acc: 0.9625
# Epoch 76/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0168 - acc: 0.9996
# Epoch 00076: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 145s 5ms/sample - loss: 0.0168 - acc: 0.9996 - val_loss: 0.1645 - val_acc: 0.9615
# Epoch 77/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0168 - acc: 0.9997
# Epoch 00077: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 146s 5ms/sample - loss: 0.0168 - acc: 0.9997 - val_loss: 0.1646 - val_acc: 0.9612
# Epoch 78/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0167 - acc: 0.9996
# Epoch 00078: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 146s 5ms/sample - loss: 0.0167 - acc: 0.9996 - val_loss: 0.1652 - val_acc: 0.9618
# Epoch 79/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0167 - acc: 0.9997
# Epoch 00079: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 145s 5ms/sample - loss: 0.0167 - acc: 0.9997 - val_loss: 0.1656 - val_acc: 0.9628
# Epoch 80/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0167 - acc: 0.9996
# Epoch 00080: val_acc did not improve from 0.96375
# 27810/27810 [==============================] - 147s 5ms/sample - loss: 0.0167 - acc: 0.9996 - val_loss: 0.1659 - val_acc: 0.9618
# Epoch 00080: early stopping

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')
plt.ylim([0.6,1])

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
scores = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# confusion matrix
Y_pred=model.predict_classes(X_test)
print(Y_pred.shape)
# Out:
# acc: 96.59%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-cc54c5cf9ee2> in <module>
#       7
#       8 # confusion matrix
# ----> 9 Y_pred=model.predict_classes(X_test)
#      10 print(Y_pred.shape)
#
# AttributeError: 'Functional' object has no attribute 'predict_classes'

# %%
from sklearn.metrics import confusion_matrix
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
