# %% [markdown]
# # CNN-LSTM自己

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-0%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-0%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (17174, 200, 9)
# (17174, 1)

# %%
#只取前列数据
X_train=X_train[:,:,0:6]#只取前
print(X_train.shape)
print(Y_train.shape)
# Out:
# (17174, 200, 6)
# (17174, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (15456, 200, 6)
# (15456, 1)
# (1718, 200, 6)
# (1718, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Import Keras
from __future__ import print_function
import keras
from keras import regularizers,Input
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax,concatenate
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
from keras.models import Model
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

print(timesteps,input_dim,len(X_train))
print(n_classes)
# Out:
# 200 6 15456
# 3

# %% [markdown]
# **LSTM Model**

# %%
def get_model():
    inp=Input(shape=(200,6))

    #CNN model
    reshape=Reshape((200,6,1))(inp)
    conv1=Conv2D(32,(18,1),activation='relu',strides=(2,1),padding='SAME',input_shape=(200,6,1))(reshape)
    maxp1=MaxPooling2D(pool_size=(2, 1))(conv1)
    conv2=Conv2D(64, (9, 1), activation='relu',padding='SAME')(maxp1)
    conv3=Conv2D(128, (3, 1), activation='relu',padding='SAME')(conv2)
    maxp3=MaxPooling2D(pool_size=(2, 1))(conv3)
    conv4=Conv2D(128, (1, 6), activation='relu', padding='VALID')(maxp3)
    cnn_out=Flatten()(conv4)


    #LSTM model
    lstm1=LSTM(64, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal')(inp)
    # Adding a dropout layer
    #model2.add(Dropout(0.25))
    batch1=BatchNormalization()(lstm1)
    lstm2=LSTM(64)(batch1)
    # Adding a dropout layer
    lstm_out=Dropout(0.5)(lstm2)

    m2=concatenate([cnn_out,lstm_out],axis=1)

    m2_out=Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                    activity_regularizer=regularizers.l1(0.01))(m2)
    model=Model(inputs=inp,outputs=m2_out)
    model.summary()
    return model

# %%
#-------------------
# Compiling the model
model=get_model()
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_acc', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.25,
    patience=8,#多少epoch，如果monitor内容没有效果就earlystop
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list = [mc,es,rp]
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 6)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 6, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 6, 32)   608         reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 6, 32)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 6, 64)    18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 6, 128)   24704       conv2d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 200, 64)      18176       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 6, 128)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 64)      256         lstm[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 1, 128)   98432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3200)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3264)         0           flatten[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            9795        concatenate[0][0]
# ==================================================================================================
# Total params: 203,491
# Trainable params: 203,363
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# Training the model
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 13910 samples, validate on 1546 samples
# Epoch 1/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.4626 - acc: 0.4272WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.47219, saving model to M2-weights-improvement-01-0.47.hdf5
# 13910/13910 [==============================] - 122s 9ms/sample - loss: 1.4626 - acc: 0.4272 - val_loss: 1.0486 - val_acc: 0.4722
# Epoch 2/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9986 - acc: 0.5059
# Epoch 00002: val_acc improved from 0.47219 to 0.56856, saving model to M2-weights-improvement-02-0.57.hdf5
# 13910/13910 [==============================] - 129s 9ms/sample - loss: 0.9986 - acc: 0.5059 - val_loss: 0.8879 - val_acc: 0.5686
# Epoch 3/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8673 - acc: 0.5881
# Epoch 00003: val_acc did not improve from 0.56856
# 13910/13910 [==============================] - 128s 9ms/sample - loss: 0.8673 - acc: 0.5881 - val_loss: 1.0478 - val_acc: 0.4838
# Epoch 4/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7624 - acc: 0.6587
# Epoch 00004: val_acc improved from 0.56856 to 0.68693, saving model to M2-weights-improvement-04-0.69.hdf5
# 13910/13910 [==============================] - 126s 9ms/sample - loss: 0.7624 - acc: 0.6587 - val_loss: 0.7058 - val_acc: 0.6869
# Epoch 5/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6741 - acc: 0.6987
# Epoch 00005: val_acc improved from 0.68693 to 0.73221, saving model to M2-weights-improvement-05-0.73.hdf5
# 13910/13910 [==============================] - 125s 9ms/sample - loss: 0.6741 - acc: 0.6987 - val_loss: 0.6463 - val_acc: 0.7322
# Epoch 6/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6285 - acc: 0.7359
# Epoch 00006: val_acc improved from 0.73221 to 0.73480, saving model to M2-weights-improvement-06-0.73.hdf5
# 13910/13910 [==============================] - 124s 9ms/sample - loss: 0.6285 - acc: 0.7359 - val_loss: 0.5937 - val_acc: 0.7348
# Epoch 7/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5686 - acc: 0.7625
# Epoch 00007: val_acc improved from 0.73480 to 0.79043, saving model to M2-weights-improvement-07-0.79.hdf5
# 13910/13910 [==============================] - 125s 9ms/sample - loss: 0.5686 - acc: 0.7625 - val_loss: 0.5305 - val_acc: 0.7904
# Epoch 8/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5182 - acc: 0.7840
# Epoch 00008: val_acc did not improve from 0.79043
# 13910/13910 [==============================] - 128s 9ms/sample - loss: 0.5182 - acc: 0.7840 - val_loss: 0.6048 - val_acc: 0.7458
# Epoch 9/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4793 - acc: 0.8043
# Epoch 00009: val_acc did not improve from 0.79043
# 13910/13910 [==============================] - 121s 9ms/sample - loss: 0.4793 - acc: 0.8043 - val_loss: 0.5949 - val_acc: 0.7600
# Epoch 10/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4327 - acc: 0.8272
# Epoch 00010: val_acc improved from 0.79043 to 0.79431, saving model to M2-weights-improvement-10-0.79.hdf5
# 13910/13910 [==============================] - 123s 9ms/sample - loss: 0.4327 - acc: 0.8272 - val_loss: 0.5512 - val_acc: 0.7943
# Epoch 11/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4053 - acc: 0.8463
# Epoch 00011: val_acc did not improve from 0.79431
# 13910/13910 [==============================] - 123s 9ms/sample - loss: 0.4053 - acc: 0.8463 - val_loss: 0.6774 - val_acc: 0.7199
# Epoch 12/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3636 - acc: 0.8673
# Epoch 00012: val_acc did not improve from 0.79431
# 13910/13910 [==============================] - 127s 9ms/sample - loss: 0.3636 - acc: 0.8673 - val_loss: 0.5901 - val_acc: 0.7865
# Epoch 13/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3454 - acc: 0.8746
# Epoch 00013: val_acc improved from 0.79431 to 0.82212, saving model to M2-weights-improvement-13-0.82.hdf5
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.3454 - acc: 0.8746 - val_loss: 0.4931 - val_acc: 0.8221
# Epoch 14/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3083 - acc: 0.8938
# Epoch 00014: val_acc improved from 0.82212 to 0.83506, saving model to M2-weights-improvement-14-0.84.hdf5
# 13910/13910 [==============================] - 129s 9ms/sample - loss: 0.3083 - acc: 0.8938 - val_loss: 0.4655 - val_acc: 0.8351
# Epoch 15/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3012 - acc: 0.9000
# Epoch 00015: val_acc did not improve from 0.83506
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.3012 - acc: 0.9000 - val_loss: 0.4853 - val_acc: 0.8131
# Epoch 16/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2664 - acc: 0.9123
# Epoch 00016: val_acc did not improve from 0.83506
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.2664 - acc: 0.9123 - val_loss: 0.5498 - val_acc: 0.7943
# Epoch 17/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2577 - acc: 0.9162
# Epoch 00017: val_acc improved from 0.83506 to 0.87387, saving model to M2-weights-improvement-17-0.87.hdf5
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.2577 - acc: 0.9162 - val_loss: 0.3784 - val_acc: 0.8739
# Epoch 18/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2287 - acc: 0.9330
# Epoch 00018: val_acc did not improve from 0.87387
# 13910/13910 [==============================] - 132s 9ms/sample - loss: 0.2287 - acc: 0.9330 - val_loss: 0.4809 - val_acc: 0.8461
# Epoch 19/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2150 - acc: 0.9389
# Epoch 00019: val_acc did not improve from 0.87387
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.2150 - acc: 0.9389 - val_loss: 0.4590 - val_acc: 0.8292
# Epoch 20/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2071 - acc: 0.9389
# Epoch 00020: val_acc did not improve from 0.87387
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.2071 - acc: 0.9389 - val_loss: 0.8176 - val_acc: 0.7451
# Epoch 21/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1862 - acc: 0.9515
# Epoch 00021: val_acc improved from 0.87387 to 0.88098, saving model to M2-weights-improvement-21-0.88.hdf5
# 13910/13910 [==============================] - 771s 55ms/sample - loss: 0.1862 - acc: 0.9515 - val_loss: 0.3811 - val_acc: 0.8810
# Epoch 22/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1861 - acc: 0.9550
# Epoch 00022: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.1861 - acc: 0.9550 - val_loss: 0.5534 - val_acc: 0.8286
# Epoch 23/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1802 - acc: 0.9531
# Epoch 00023: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 127s 9ms/sample - loss: 0.1802 - acc: 0.9531 - val_loss: 0.3932 - val_acc: 0.8719
# Epoch 24/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1621 - acc: 0.9620
# Epoch 00024: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 118s 8ms/sample - loss: 0.1621 - acc: 0.9620 - val_loss: 0.3947 - val_acc: 0.8758
# Epoch 25/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1646 - acc: 0.9605
# Epoch 00025: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 130s 9ms/sample - loss: 0.1646 - acc: 0.9605 - val_loss: 0.4288 - val_acc: 0.8428
# Epoch 26/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1442 - acc: 0.9689
# Epoch 00026: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.1442 - acc: 0.9689 - val_loss: 0.6242 - val_acc: 0.8066
# Epoch 27/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1508 - acc: 0.9638
# Epoch 00027: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 134s 10ms/sample - loss: 0.1508 - acc: 0.9638 - val_loss: 0.4640 - val_acc: 0.8454
# Epoch 28/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1328 - acc: 0.9684
# Epoch 00028: val_acc did not improve from 0.88098
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.1328 - acc: 0.9684 - val_loss: 0.4107 - val_acc: 0.8700
# Epoch 29/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1296 - acc: 0.9730
# Epoch 00029: val_acc improved from 0.88098 to 0.88228, saving model to M2-weights-improvement-29-0.88.hdf5
# 13910/13910 [==============================] - 130s 9ms/sample - loss: 0.1296 - acc: 0.9730 - val_loss: 0.3827 - val_acc: 0.8823
# Epoch 30/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1373 - acc: 0.9694
# Epoch 00030: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 132s 9ms/sample - loss: 0.1373 - acc: 0.9694 - val_loss: 0.3814 - val_acc: 0.8700
# Epoch 31/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1140 - acc: 0.9775
# Epoch 00031: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 137s 10ms/sample - loss: 0.1140 - acc: 0.9775 - val_loss: 0.4354 - val_acc: 0.8713
# Epoch 32/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1341 - acc: 0.9710
# Epoch 00032: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.1341 - acc: 0.9710 - val_loss: 0.4382 - val_acc: 0.8499
# Epoch 33/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1063 - acc: 0.9810
# Epoch 00033: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.1063 - acc: 0.9810 - val_loss: 0.4436 - val_acc: 0.8797
# Epoch 34/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1127 - acc: 0.9777
# Epoch 00034: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 133s 10ms/sample - loss: 0.1127 - acc: 0.9777 - val_loss: 0.4312 - val_acc: 0.8713
# Epoch 35/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1152 - acc: 0.9751
# Epoch 00035: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 131s 9ms/sample - loss: 0.1152 - acc: 0.9751 - val_loss: 0.3966 - val_acc: 0.8758
# Epoch 36/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1062 - acc: 0.9796
# Epoch 00036: val_acc did not improve from 0.88228
# 13910/13910 [==============================] - 136s 10ms/sample - loss: 0.1062 - acc: 0.9796 - val_loss: 0.5385 - val_acc: 0.8351
# Epoch 37/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1065 - acc: 0.9804
# Epoch 00037: val_acc improved from 0.88228 to 0.88422, saving model to M2-weights-improvement-37-0.88.hdf5
# 13910/13910 [==============================] - 132s 10ms/sample - loss: 0.1065 - acc: 0.9804 - val_loss: 0.3918 - val_acc: 0.8842
# Epoch 38/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0984 - acc: 0.9824
# Epoch 00038: val_acc did not improve from 0.88422
# 13910/13910 [==============================] - 132s 9ms/sample - loss: 0.0984 - acc: 0.9824 - val_loss: 0.6632 - val_acc: 0.8228
# Epoch 39/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1007 - acc: 0.9792
# Epoch 00039: val_acc did not improve from 0.88422
# 13910/13910 [==============================] - 129s 9ms/sample - loss: 0.1007 - acc: 0.9792 - val_loss: 0.4529 - val_acc: 0.8777
# Epoch 40/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1141 - acc: 0.9776
# Epoch 00040: val_acc did not improve from 0.88422
# 13910/13910 [==============================] - 143s 10ms/sample - loss: 0.1141 - acc: 0.9776 - val_loss: 0.4071 - val_acc: 0.8842
# Epoch 41/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0956 - acc: 0.9820
# Epoch 00041: val_acc improved from 0.88422 to 0.88810, saving model to M2-weights-improvement-41-0.89.hdf5
# 13910/13910 [==============================] - 138s 10ms/sample - loss: 0.0956 - acc: 0.9820 - val_loss: 0.4056 - val_acc: 0.8881
# Epoch 42/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1046 - acc: 0.9804
# Epoch 00042: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 123s 9ms/sample - loss: 0.1046 - acc: 0.9804 - val_loss: 0.3393 - val_acc: 0.8875
# Epoch 43/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0807 - acc: 0.9885
# Epoch 00043: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 117s 8ms/sample - loss: 0.0807 - acc: 0.9885 - val_loss: 0.6522 - val_acc: 0.8415
# Epoch 44/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1051 - acc: 0.9802
# Epoch 00044: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.1051 - acc: 0.9802 - val_loss: 0.4702 - val_acc: 0.8732
# Epoch 45/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0944 - acc: 0.9804
# Epoch 00045: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 117s 8ms/sample - loss: 0.0944 - acc: 0.9804 - val_loss: 0.3933 - val_acc: 0.8823
# Epoch 46/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0933 - acc: 0.9812
# Epoch 00046: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 125s 9ms/sample - loss: 0.0933 - acc: 0.9812 - val_loss: 0.4346 - val_acc: 0.8849
# Epoch 47/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1023 - acc: 0.9815
# Epoch 00047: val_acc did not improve from 0.88810
# 13910/13910 [==============================] - 118s 8ms/sample - loss: 0.1023 - acc: 0.9815 - val_loss: 0.5068 - val_acc: 0.8538
# Epoch 48/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0949 - acc: 0.9816
# Epoch 00048: val_acc improved from 0.88810 to 0.88875, saving model to M2-weights-improvement-48-0.89.hdf5
# 13910/13910 [==============================] - 114s 8ms/sample - loss: 0.0949 - acc: 0.9816 - val_loss: 0.4030 - val_acc: 0.8887
# Epoch 49/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1099 - acc: 0.9748
# Epoch 00049: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 118s 9ms/sample - loss: 0.1099 - acc: 0.9748 - val_loss: 0.3452 - val_acc: 0.8739
# Epoch 50/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0637 - acc: 0.9916
# Epoch 00050: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 116s 8ms/sample - loss: 0.0637 - acc: 0.9916 - val_loss: 0.4260 - val_acc: 0.8881
# Epoch 51/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1029 - acc: 0.9812
# Epoch 00051: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 118s 8ms/sample - loss: 0.1029 - acc: 0.9812 - val_loss: 0.3619 - val_acc: 0.8849
# Epoch 52/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0716 - acc: 0.9894
# Epoch 00052: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.0716 - acc: 0.9894 - val_loss: 0.4286 - val_acc: 0.8790
# Epoch 53/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1017 - acc: 0.9825
# Epoch 00053: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 114s 8ms/sample - loss: 0.1017 - acc: 0.9825 - val_loss: 0.4982 - val_acc: 0.8092
# Epoch 54/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0685 - acc: 0.9884
# Epoch 00054: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 120s 9ms/sample - loss: 0.0685 - acc: 0.9884 - val_loss: 0.4601 - val_acc: 0.8797
# Epoch 55/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1067 - acc: 0.9793
# Epoch 00055: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 124s 9ms/sample - loss: 0.1067 - acc: 0.9793 - val_loss: 0.3698 - val_acc: 0.8810
# Epoch 56/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0945 - acc: 0.9872
# Epoch 00056: val_acc did not improve from 0.88875
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13910/13910 [==============================] - 118s 9ms/sample - loss: 0.0945 - acc: 0.9872 - val_loss: 0.4521 - val_acc: 0.8810
# Epoch 57/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0285 - acc: 0.9998
# Epoch 00057: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.0285 - acc: 0.9998 - val_loss: 0.4538 - val_acc: 0.8823
# Epoch 58/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0256 - acc: 0.9998
# Epoch 00058: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 116s 8ms/sample - loss: 0.0256 - acc: 0.9998 - val_loss: 0.4379 - val_acc: 0.8836
# Epoch 59/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0236 - acc: 0.9998
# Epoch 00059: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 114s 8ms/sample - loss: 0.0236 - acc: 0.9998 - val_loss: 0.4230 - val_acc: 0.8849
# Epoch 60/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0229 - acc: 0.9997
# Epoch 00060: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 116s 8ms/sample - loss: 0.0229 - acc: 0.9997 - val_loss: 0.4307 - val_acc: 0.8797
# Epoch 61/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0217 - acc: 0.9996
# Epoch 00061: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.0217 - acc: 0.9996 - val_loss: 0.5045 - val_acc: 0.8765
# Epoch 62/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0221 - acc: 0.9992
# Epoch 00062: val_acc did not improve from 0.88875
# 13910/13910 [==============================] - 117s 8ms/sample - loss: 0.0221 - acc: 0.9992 - val_loss: 0.4044 - val_acc: 0.8816
# Epoch 00062: early stopping

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')
plt.ylim([0.6,1])

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
# model.compile(loss='sparse_categorical_crossentropy',
#               optimizer='Adam',
#               metrics=['accuracy'])
scores = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# # confusion matrix
# Y_pred=model.predict_classes(X_test)
# print(Y_pred.shape)
# Out:
# acc: 89.64%

# %%
from sklearn.metrics import confusion_matrix
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3d60707012a4> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2 cm_cmap=plt.cm.Greens
# ----> 3 cm = confusion_matrix(Y_test,Y_pred)
#       4
#       5
#
# NameError: name 'Y_pred' is not defined
