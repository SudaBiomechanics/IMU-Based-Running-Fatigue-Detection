# %% [markdown]
# # CNN-LSTM自己

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-50%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-50%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (34334, 200, 9)
# (34334, 1)

# %%
#只取前列数据
X_train=X_train[:,:,0:6]#只取前
print(X_train.shape)
print(Y_train.shape)
# Out:
# (34334, 200, 6)
# (34334, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (30900, 200, 6)
# (30900, 1)
# (3434, 200, 6)
# (3434, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Import Keras
from __future__ import print_function
import keras
from keras import regularizers,Input
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax,concatenate
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
from keras.models import Model
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

print(timesteps,input_dim,len(X_train))
print(n_classes)
# Out:
# 200 6 30900
# 3

# %% [markdown]
# **LSTM Model**

# %%
def get_model():
    inp=Input(shape=(200,6))

    #CNN model
    reshape=Reshape((200,6,1))(inp)
    conv1=Conv2D(32,(18,1),activation='relu',strides=(2,1),padding='SAME',input_shape=(200,6,1))(reshape)
    maxp1=MaxPooling2D(pool_size=(2, 1))(conv1)
    conv2=Conv2D(64, (9, 1), activation='relu',padding='SAME')(maxp1)
    conv3=Conv2D(128, (3, 1), activation='relu',padding='SAME')(conv2)
    maxp3=MaxPooling2D(pool_size=(2, 1))(conv3)
    conv4=Conv2D(128, (1, 6), activation='relu', padding='VALID')(maxp3)
    cnn_out=Flatten()(conv4)


    #LSTM model
    lstm1=LSTM(64, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal')(inp)
    # Adding a dropout layer
    #model2.add(Dropout(0.25))
    batch1=BatchNormalization()(lstm1)
    lstm2=LSTM(64)(batch1)
    # Adding a dropout layer
    lstm_out=Dropout(0.5)(lstm2)

    m2=concatenate([cnn_out,lstm_out],axis=1)

    m2_out=Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                    activity_regularizer=regularizers.l1(0.01))(m2)
    model=Model(inputs=inp,outputs=m2_out)
    model.summary()
    return model

# %%
#-------------------
# Compiling the model
model=get_model()
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_loss', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.25,
    patience=8,#多少epoch，如果monitor内容没有效果就earlystop
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list = [mc,es,rp]
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 6)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 6, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 6, 32)   608         reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 6, 32)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 6, 64)    18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 6, 128)   24704       conv2d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 200, 64)      18176       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 6, 128)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 64)      256         lstm[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 1, 128)   98432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3200)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3264)         0           flatten[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            9795        concatenate[0][0]
# ==================================================================================================
# Total params: 203,491
# Trainable params: 203,363
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# Training the model
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 27810 samples, validate on 3090 samples
# Epoch 1/200
# 27810/27810 [==============================] - ETA: 0s - loss: 1.1977 - acc: 0.4676WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.55113, saving model to M2-weights-improvement-01-0.55.hdf5
# 27810/27810 [==============================] - 234s 8ms/sample - loss: 1.1977 - acc: 0.4676 - val_loss: 0.9441 - val_acc: 0.5511
# Epoch 2/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.7934 - acc: 0.6279
# Epoch 00002: val_acc improved from 0.55113 to 0.71100, saving model to M2-weights-improvement-02-0.71.hdf5
# 27810/27810 [==============================] - 271s 10ms/sample - loss: 0.7934 - acc: 0.6279 - val_loss: 0.6723 - val_acc: 0.7110
# Epoch 3/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.6353 - acc: 0.7156
# Epoch 00003: val_acc improved from 0.71100 to 0.71489, saving model to M2-weights-improvement-03-0.71.hdf5
# 27810/27810 [==============================] - 251s 9ms/sample - loss: 0.6353 - acc: 0.7156 - val_loss: 0.6404 - val_acc: 0.7149
# Epoch 4/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.5232 - acc: 0.7804
# Epoch 00004: val_acc improved from 0.71489 to 0.71942, saving model to M2-weights-improvement-04-0.72.hdf5
# 27810/27810 [==============================] - 257s 9ms/sample - loss: 0.5232 - acc: 0.7804 - val_loss: 0.6551 - val_acc: 0.7194
# Epoch 5/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.4532 - acc: 0.8141
# Epoch 00005: val_acc improved from 0.71942 to 0.72298, saving model to M2-weights-improvement-05-0.72.hdf5
# 27810/27810 [==============================] - 251s 9ms/sample - loss: 0.4532 - acc: 0.8141 - val_loss: 0.6900 - val_acc: 0.7230
# Epoch 6/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3980 - acc: 0.8426
# Epoch 00006: val_acc improved from 0.72298 to 0.82783, saving model to M2-weights-improvement-06-0.83.hdf5
# 27810/27810 [==============================] - 254s 9ms/sample - loss: 0.3980 - acc: 0.8426 - val_loss: 0.4297 - val_acc: 0.8278
# Epoch 7/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3524 - acc: 0.8657
# Epoch 00007: val_acc improved from 0.82783 to 0.87152, saving model to M2-weights-improvement-07-0.87.hdf5
# 27810/27810 [==============================] - 258s 9ms/sample - loss: 0.3524 - acc: 0.8657 - val_loss: 0.3571 - val_acc: 0.8715
# Epoch 8/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.3126 - acc: 0.8863
# Epoch 00008: val_acc improved from 0.87152 to 0.90583, saving model to M2-weights-improvement-08-0.91.hdf5
# 27810/27810 [==============================] - 282s 10ms/sample - loss: 0.3126 - acc: 0.8863 - val_loss: 0.2816 - val_acc: 0.9058
# Epoch 9/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2812 - acc: 0.9013
# Epoch 00009: val_acc did not improve from 0.90583
# 27810/27810 [==============================] - 256s 9ms/sample - loss: 0.2812 - acc: 0.9013 - val_loss: 0.4197 - val_acc: 0.8414
# Epoch 10/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2568 - acc: 0.9140
# Epoch 00010: val_acc improved from 0.90583 to 0.90680, saving model to M2-weights-improvement-10-0.91.hdf5
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.2568 - acc: 0.9140 - val_loss: 0.2746 - val_acc: 0.9068
# Epoch 11/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2302 - acc: 0.9231
# Epoch 00011: val_acc improved from 0.90680 to 0.91942, saving model to M2-weights-improvement-11-0.92.hdf5
# 27810/27810 [==============================] - 249s 9ms/sample - loss: 0.2302 - acc: 0.9231 - val_loss: 0.2524 - val_acc: 0.9194
# Epoch 12/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.2192 - acc: 0.9315
# Epoch 00012: val_acc improved from 0.91942 to 0.92654, saving model to M2-weights-improvement-12-0.93.hdf5
# 27810/27810 [==============================] - 244s 9ms/sample - loss: 0.2192 - acc: 0.9315 - val_loss: 0.2315 - val_acc: 0.9265
# Epoch 13/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1996 - acc: 0.9380
# Epoch 00013: val_acc improved from 0.92654 to 0.93430, saving model to M2-weights-improvement-13-0.93.hdf5
# 27810/27810 [==============================] - 253s 9ms/sample - loss: 0.1996 - acc: 0.9380 - val_loss: 0.2117 - val_acc: 0.9343
# Epoch 14/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1779 - acc: 0.9454
# Epoch 00014: val_acc did not improve from 0.93430
# 27810/27810 [==============================] - 248s 9ms/sample - loss: 0.1779 - acc: 0.9454 - val_loss: 0.2522 - val_acc: 0.9155
# Epoch 15/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1659 - acc: 0.9507
# Epoch 00015: val_acc did not improve from 0.93430
# 27810/27810 [==============================] - 242s 9ms/sample - loss: 0.1659 - acc: 0.9507 - val_loss: 0.2359 - val_acc: 0.9217
# Epoch 16/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1573 - acc: 0.9544
# Epoch 00016: val_acc improved from 0.93430 to 0.94563, saving model to M2-weights-improvement-16-0.95.hdf5
# 27810/27810 [==============================] - 245s 9ms/sample - loss: 0.1573 - acc: 0.9544 - val_loss: 0.1836 - val_acc: 0.9456
# Epoch 17/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1447 - acc: 0.9604
# Epoch 00017: val_acc did not improve from 0.94563
# 27810/27810 [==============================] - 249s 9ms/sample - loss: 0.1447 - acc: 0.9604 - val_loss: 0.1993 - val_acc: 0.9366
# Epoch 18/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1297 - acc: 0.9655
# Epoch 00018: val_acc did not improve from 0.94563
# 27810/27810 [==============================] - 255s 9ms/sample - loss: 0.1297 - acc: 0.9655 - val_loss: 0.1898 - val_acc: 0.9401
# Epoch 19/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1237 - acc: 0.9686
# Epoch 00019: val_acc did not improve from 0.94563
# 27810/27810 [==============================] - 259s 9ms/sample - loss: 0.1237 - acc: 0.9686 - val_loss: 0.2008 - val_acc: 0.9369
# Epoch 20/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1178 - acc: 0.9697
# Epoch 00020: val_acc did not improve from 0.94563
# 27810/27810 [==============================] - 262s 9ms/sample - loss: 0.1178 - acc: 0.9697 - val_loss: 0.1876 - val_acc: 0.9401
# Epoch 21/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1151 - acc: 0.9715
# Epoch 00021: val_acc improved from 0.94563 to 0.94725, saving model to M2-weights-improvement-21-0.95.hdf5
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.1151 - acc: 0.9715 - val_loss: 0.1660 - val_acc: 0.9472
# Epoch 22/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1085 - acc: 0.9753
# Epoch 00022: val_acc did not improve from 0.94725
# 27810/27810 [==============================] - 266s 10ms/sample - loss: 0.1085 - acc: 0.9753 - val_loss: 0.1980 - val_acc: 0.9350
# Epoch 23/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.1058 - acc: 0.9780
# Epoch 00023: val_acc did not improve from 0.94725
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.1058 - acc: 0.9780 - val_loss: 0.4742 - val_acc: 0.8612
# Epoch 24/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0991 - acc: 0.9779
# Epoch 00024: val_acc did not improve from 0.94725
# 27810/27810 [==============================] - 265s 10ms/sample - loss: 0.0991 - acc: 0.9779 - val_loss: 0.1934 - val_acc: 0.9443
# Epoch 25/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0958 - acc: 0.9792
# Epoch 00025: val_acc improved from 0.94725 to 0.95340, saving model to M2-weights-improvement-25-0.95.hdf5
# 27810/27810 [==============================] - 266s 10ms/sample - loss: 0.0958 - acc: 0.9792 - val_loss: 0.1681 - val_acc: 0.9534
# Epoch 26/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0836 - acc: 0.9839
# Epoch 00026: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 264s 10ms/sample - loss: 0.0836 - acc: 0.9839 - val_loss: 0.9250 - val_acc: 0.7896
# Epoch 27/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0913 - acc: 0.9811
# Epoch 00027: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.0913 - acc: 0.9811 - val_loss: 0.2189 - val_acc: 0.9307
# Epoch 28/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0839 - acc: 0.9825
# Epoch 00028: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0839 - acc: 0.9825 - val_loss: 0.1688 - val_acc: 0.9447
# Epoch 29/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0835 - acc: 0.9831
# Epoch 00029: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0835 - acc: 0.9831 - val_loss: 0.1701 - val_acc: 0.9492
# Epoch 30/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0807 - acc: 0.9848
# Epoch 00030: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0807 - acc: 0.9848 - val_loss: 0.1557 - val_acc: 0.9492
# Epoch 31/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0717 - acc: 0.9856
# Epoch 00031: val_acc did not improve from 0.95340
# 27810/27810 [==============================] - 264s 9ms/sample - loss: 0.0717 - acc: 0.9856 - val_loss: 0.1759 - val_acc: 0.9492
# Epoch 32/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0814 - acc: 0.9833
# Epoch 00032: val_acc improved from 0.95340 to 0.95469, saving model to M2-weights-improvement-32-0.95.hdf5
# 27810/27810 [==============================] - 264s 9ms/sample - loss: 0.0814 - acc: 0.9833 - val_loss: 0.1555 - val_acc: 0.9547
# Epoch 33/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0703 - acc: 0.9867
# Epoch 00033: val_acc did not improve from 0.95469
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0703 - acc: 0.9867 - val_loss: 0.1752 - val_acc: 0.9508
# Epoch 34/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0693 - acc: 0.9865
# Epoch 00034: val_acc did not improve from 0.95469
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.0693 - acc: 0.9865 - val_loss: 0.1638 - val_acc: 0.9515
# Epoch 35/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0710 - acc: 0.9863
# Epoch 00035: val_acc did not improve from 0.95469
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0710 - acc: 0.9863 - val_loss: 0.1785 - val_acc: 0.9456
# Epoch 36/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0694 - acc: 0.9867
# Epoch 00036: val_acc improved from 0.95469 to 0.95566, saving model to M2-weights-improvement-36-0.96.hdf5
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0694 - acc: 0.9867 - val_loss: 0.1579 - val_acc: 0.9557
# Epoch 37/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0712 - acc: 0.9869
# Epoch 00037: val_acc improved from 0.95566 to 0.95761, saving model to M2-weights-improvement-37-0.96.hdf5
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0712 - acc: 0.9869 - val_loss: 0.1483 - val_acc: 0.9576
# Epoch 38/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0666 - acc: 0.9894
# Epoch 00038: val_acc did not improve from 0.95761
# 27810/27810 [==============================] - 264s 9ms/sample - loss: 0.0666 - acc: 0.9894 - val_loss: 0.2036 - val_acc: 0.9417
# Epoch 39/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0685 - acc: 0.9871
# Epoch 00039: val_acc did not improve from 0.95761
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0685 - acc: 0.9871 - val_loss: 0.1528 - val_acc: 0.9550
# Epoch 40/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0626 - acc: 0.9879
# Epoch 00040: val_acc did not improve from 0.95761
# 27810/27810 [==============================] - 265s 10ms/sample - loss: 0.0626 - acc: 0.9879 - val_loss: 0.1716 - val_acc: 0.9524
# Epoch 41/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0591 - acc: 0.9904
# Epoch 00041: val_acc did not improve from 0.95761
# 27810/27810 [==============================] - 270s 10ms/sample - loss: 0.0591 - acc: 0.9904 - val_loss: 0.1897 - val_acc: 0.9495
# Epoch 42/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0636 - acc: 0.9871
# Epoch 00042: val_acc did not improve from 0.95761
# 27810/27810 [==============================] - 262s 9ms/sample - loss: 0.0636 - acc: 0.9871 - val_loss: 0.1756 - val_acc: 0.9540
# Epoch 43/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0635 - acc: 0.9885
# Epoch 00043: val_acc improved from 0.95761 to 0.95793, saving model to M2-weights-improvement-43-0.96.hdf5
# 27810/27810 [==============================] - 264s 9ms/sample - loss: 0.0635 - acc: 0.9885 - val_loss: 0.1552 - val_acc: 0.9579
# Epoch 44/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0589 - acc: 0.9896
# Epoch 00044: val_acc improved from 0.95793 to 0.96278, saving model to M2-weights-improvement-44-0.96.hdf5
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0589 - acc: 0.9896 - val_loss: 0.1503 - val_acc: 0.9628
# Epoch 45/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0616 - acc: 0.9889
# Epoch 00045: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 265s 10ms/sample - loss: 0.0616 - acc: 0.9889 - val_loss: 0.1564 - val_acc: 0.9534
# Epoch 46/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0566 - acc: 0.9895
# Epoch 00046: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 261s 9ms/sample - loss: 0.0566 - acc: 0.9895 - val_loss: 0.1545 - val_acc: 0.9547
# Epoch 47/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0509 - acc: 0.9918
# Epoch 00047: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 267s 10ms/sample - loss: 0.0509 - acc: 0.9918 - val_loss: 1.5224 - val_acc: 0.7405
# Epoch 48/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0608 - acc: 0.9890
# Epoch 00048: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 268s 10ms/sample - loss: 0.0608 - acc: 0.9890 - val_loss: 0.1621 - val_acc: 0.9563
# Epoch 49/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0567 - acc: 0.9899
# Epoch 00049: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0567 - acc: 0.9899 - val_loss: 0.1542 - val_acc: 0.9599
# Epoch 50/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0598 - acc: 0.9899
# Epoch 00050: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 263s 9ms/sample - loss: 0.0598 - acc: 0.9899 - val_loss: 0.1506 - val_acc: 0.9570
# Epoch 51/200
# 27810/27810 [==============================] - ETA: 0s - loss: 0.0563 - acc: 0.9900
# Epoch 00051: val_acc did not improve from 0.96278
# 27810/27810 [==============================] - 264s 9ms/sample - loss: 0.0563 - acc: 0.9900 - val_loss: 0.1524 - val_acc: 0.9557
# Epoch 00051: early stopping

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')
plt.ylim([0.6,1])

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
# model.compile(loss='sparse_categorical_crossentropy',
#               optimizer='Adam',
#               metrics=['accuracy'])
scores = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# # confusion matrix
# Y_pred=model.predict_classes(X_test)
# print(Y_pred.shape)
# Out:
# acc: 95.66%

# %%
from sklearn.metrics import confusion_matrix
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3d60707012a4> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2 cm_cmap=plt.cm.Greens
# ----> 3 cm = confusion_matrix(Y_test,Y_pred)
#       4
#       5
#
# NameError: name 'Y_pred' is not defined
