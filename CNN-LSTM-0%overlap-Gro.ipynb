# %% [markdown]
# # CNN-LSTM自己

# %%
import tensorflow.compat.v1  as tf
import numpy as np
import os,sys
tf.compat.v1.disable_eager_execution()
import scipy.io as scio

# %%
X_train_mat = scio.loadmat('X_train-3Classes-0%overlap.mat')
key_name = list(X_train_mat.keys())[-1]
X_train=X_train_mat[key_name]
print(X_train.shape)

Y_train_mat = scio.loadmat('Y_train-3Classes-0%overlap.mat')
key_name = list(Y_train_mat.keys())[-1]
Y_train=Y_train_mat[key_name]
print(Y_train.shape)
# Out:
# (17174, 200, 9)
# (17174, 1)

# %%
#只取前列数据
X_train=X_train[:,:,3:6]#只取前
print(X_train.shape)
print(Y_train.shape)
# Out:
# (17174, 200, 3)
# (17174, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state = 0)
#X_test, X_valid, Y_test, Y_valid = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (15456, 200, 3)
# (15456, 1)
# (1718, 200, 3)
# (1718, 1)

# %%
np.random.seed(42)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(42)
# Configuring a session
session_conf = tf.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Import Keras
from __future__ import print_function
import keras
from keras import regularizers,Input
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten, Reshape, Softmax,concatenate
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, TimeDistributed,LSTM,Bidirectional,BatchNormalization
from keras.models import Model
#from keras import backend as K
from tensorflow.compat.v1.keras import backend as K
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# callbacks:
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Initializing parameters
epochs = 200
batch_size = 256
timesteps = 200
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)
#input_shape = (timesteps, input_dim)

print(timesteps,input_dim,len(X_train))
print(n_classes)
# Out:
# 200 3 15456
# 3

# %% [markdown]
# **LSTM Model**

# %%
def get_model():
    inp=Input(shape=(200,3))

    #CNN model
    reshape=Reshape((200,3,1))(inp)
    conv1=Conv2D(32,(18,1),activation='relu',strides=(2,1),padding='SAME',input_shape=(200,3,1))(reshape)
    maxp1=MaxPooling2D(pool_size=(2, 1))(conv1)
    conv2=Conv2D(64, (9, 1), activation='relu',padding='SAME')(maxp1)
    conv3=Conv2D(128, (3, 1), activation='relu',padding='SAME')(conv2)
    maxp3=MaxPooling2D(pool_size=(2, 1))(conv3)
    conv4=Conv2D(128, (1, 3), activation='relu', padding='VALID')(maxp3)
    cnn_out=Flatten()(conv4)


    #LSTM model
    lstm1=LSTM(64, return_sequences=True, input_shape=(timesteps, input_dim), kernel_initializer='glorot_normal')(inp)
    # Adding a dropout layer
    #model2.add(Dropout(0.25))
    batch1=BatchNormalization()(lstm1)
    lstm2=LSTM(64)(batch1)
    # Adding a dropout layer
    lstm_out=Dropout(0.5)(lstm2)

    m2=concatenate([cnn_out,lstm_out],axis=1)

    m2_out=Dense(n_classes, activation='softmax',kernel_regularizer=regularizers.l2(0.01),
                    activity_regularizer=regularizers.l1(0.01))(m2)
    model=Model(inputs=inp,outputs=m2_out)
    model.summary()
    return model

# %%
#-------------------
# Compiling the model
model=get_model()
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

filepath="M2-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

tb = TensorBoard(log_dir='./logs',  # log 目录
                 histogram_freq=1,  # 按照何等频率（epoch）来计算直方图，0为不计算
                 batch_size=64,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0,
                 embeddings_layer_names=None,
                 embeddings_metadata=None)

es=EarlyStopping(monitor='val_loss', patience=14, verbose=2)
rp=ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.25,
    patience=8,#多少epoch，如果monitor内容没有效果就earlystop
    verbose=2,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0
)

# callbacks_list = [mc,tb,es,rp]
callbacks_list = [mc,es,rp]
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 3)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 200, 3, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 3, 32)   608         reshape[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 3, 32)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 50, 3, 64)    18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 3, 128)   24704       conv2d_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 200, 64)      17408       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 3, 128)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 64)      256         lstm[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 1, 128)   49280       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           33024       batch_normalization[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3200)         0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3264)         0           flatten[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            9795        concatenate[0][0]
# ==================================================================================================
# Total params: 153,571
# Trainable params: 153,443
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
# Training the model
#model.load_weights("M-weights-improvement-19-0.93.hdf5")
history=model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_split=0.1,
          epochs=epochs,
          callbacks=callbacks_list)
# Out:
# Train on 13910 samples, validate on 1546 samples
# Epoch 1/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.1237 - acc: 0.4149WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\keras\engine\training_v1.py:2048: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#
# Epoch 00001: val_acc improved from -inf to 0.41332, saving model to M2-weights-improvement-01-0.41.hdf5
# 13910/13910 [==============================] - 107s 8ms/sample - loss: 1.1237 - acc: 0.4149 - val_loss: 1.4346 - val_acc: 0.4133
# Epoch 2/200
# 13910/13910 [==============================] - ETA: 0s - loss: 1.0380 - acc: 0.4735
# Epoch 00002: val_acc improved from 0.41332 to 0.50323, saving model to M2-weights-improvement-02-0.50.hdf5
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 1.0380 - acc: 0.4735 - val_loss: 0.9961 - val_acc: 0.5032
# Epoch 3/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9796 - acc: 0.5132
# Epoch 00003: val_acc did not improve from 0.50323
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.9796 - acc: 0.5132 - val_loss: 1.0237 - val_acc: 0.4424
# Epoch 4/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.9192 - acc: 0.5694
# Epoch 00004: val_acc improved from 0.50323 to 0.62743, saving model to M2-weights-improvement-04-0.63.hdf5
# 13910/13910 [==============================] - 99s 7ms/sample - loss: 0.9192 - acc: 0.5694 - val_loss: 0.8217 - val_acc: 0.6274
# Epoch 5/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8569 - acc: 0.6065
# Epoch 00005: val_acc improved from 0.62743 to 0.66624, saving model to M2-weights-improvement-05-0.67.hdf5
# 13910/13910 [==============================] - 100s 7ms/sample - loss: 0.8569 - acc: 0.6065 - val_loss: 0.7626 - val_acc: 0.6662
# Epoch 6/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.8037 - acc: 0.6408
# Epoch 00006: val_acc did not improve from 0.66624
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.8037 - acc: 0.6408 - val_loss: 1.1327 - val_acc: 0.5149
# Epoch 7/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.7499 - acc: 0.6719
# Epoch 00007: val_acc improved from 0.66624 to 0.71734, saving model to M2-weights-improvement-07-0.72.hdf5
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.7499 - acc: 0.6719 - val_loss: 0.6561 - val_acc: 0.7173
# Epoch 8/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6996 - acc: 0.6964
# Epoch 00008: val_acc did not improve from 0.71734
# 13910/13910 [==============================] - 109s 8ms/sample - loss: 0.6996 - acc: 0.6964 - val_loss: 0.6754 - val_acc: 0.7167
# Epoch 9/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6516 - acc: 0.7287
# Epoch 00009: val_acc did not improve from 0.71734
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.6516 - acc: 0.7287 - val_loss: 0.7934 - val_acc: 0.6565
# Epoch 10/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.6000 - acc: 0.7525
# Epoch 00010: val_acc did not improve from 0.71734
# 13910/13910 [==============================] - 101s 7ms/sample - loss: 0.6000 - acc: 0.7525 - val_loss: 0.9650 - val_acc: 0.6235
# Epoch 11/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5777 - acc: 0.7619
# Epoch 00011: val_acc improved from 0.71734 to 0.80272, saving model to M2-weights-improvement-11-0.80.hdf5
# 13910/13910 [==============================] - 107s 8ms/sample - loss: 0.5777 - acc: 0.7619 - val_loss: 0.5242 - val_acc: 0.8027
# Epoch 12/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5340 - acc: 0.7910
# Epoch 00012: val_acc did not improve from 0.80272
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.5340 - acc: 0.7910 - val_loss: 0.8188 - val_acc: 0.6494
# Epoch 13/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.5009 - acc: 0.8070
# Epoch 00013: val_acc did not improve from 0.80272
# 13910/13910 [==============================] - 104s 8ms/sample - loss: 0.5009 - acc: 0.8070 - val_loss: 0.6868 - val_acc: 0.6999
# Epoch 14/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4836 - acc: 0.8167
# Epoch 00014: val_acc did not improve from 0.80272
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.4836 - acc: 0.8167 - val_loss: 0.6709 - val_acc: 0.7109
# Epoch 15/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4639 - acc: 0.8251
# Epoch 00015: val_acc did not improve from 0.80272
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.4639 - acc: 0.8251 - val_loss: 0.5774 - val_acc: 0.7678
# Epoch 16/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4335 - acc: 0.8351
# Epoch 00016: val_acc improved from 0.80272 to 0.85123, saving model to M2-weights-improvement-16-0.85.hdf5
# 13910/13910 [==============================] - 120s 9ms/sample - loss: 0.4335 - acc: 0.8351 - val_loss: 0.4088 - val_acc: 0.8512
# Epoch 17/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4134 - acc: 0.8469
# Epoch 00017: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 118s 8ms/sample - loss: 0.4134 - acc: 0.8469 - val_loss: 0.4332 - val_acc: 0.8331
# Epoch 18/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.4121 - acc: 0.8497
# Epoch 00018: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.4121 - acc: 0.8497 - val_loss: 0.4368 - val_acc: 0.8383
# Epoch 19/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3809 - acc: 0.8607
# Epoch 00019: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 122s 9ms/sample - loss: 0.3809 - acc: 0.8607 - val_loss: 0.4399 - val_acc: 0.8228
# Epoch 20/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3454 - acc: 0.8778
# Epoch 00020: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 112s 8ms/sample - loss: 0.3454 - acc: 0.8778 - val_loss: 0.8346 - val_acc: 0.6863
# Epoch 21/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3534 - acc: 0.8750
# Epoch 00021: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 104s 7ms/sample - loss: 0.3534 - acc: 0.8750 - val_loss: 0.4057 - val_acc: 0.8467
# Epoch 22/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3446 - acc: 0.8770
# Epoch 00022: val_acc did not improve from 0.85123
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3446 - acc: 0.8770 - val_loss: 0.4929 - val_acc: 0.8085
# Epoch 23/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3230 - acc: 0.8876
# Epoch 00023: val_acc improved from 0.85123 to 0.88163, saving model to M2-weights-improvement-23-0.88.hdf5
# 13910/13910 [==============================] - 115s 8ms/sample - loss: 0.3230 - acc: 0.8876 - val_loss: 0.3391 - val_acc: 0.8816
# Epoch 24/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3045 - acc: 0.8957
# Epoch 00024: val_acc did not improve from 0.88163
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.3045 - acc: 0.8957 - val_loss: 0.5670 - val_acc: 0.7853
# Epoch 25/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.3010 - acc: 0.8967
# Epoch 00025: val_acc did not improve from 0.88163
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.3010 - acc: 0.8967 - val_loss: 0.3480 - val_acc: 0.8706
# Epoch 26/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2814 - acc: 0.9041
# Epoch 00026: val_acc did not improve from 0.88163
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.2814 - acc: 0.9041 - val_loss: 0.4348 - val_acc: 0.8422
# Epoch 27/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2736 - acc: 0.9098
# Epoch 00027: val_acc improved from 0.88163 to 0.88422, saving model to M2-weights-improvement-27-0.88.hdf5
# 13910/13910 [==============================] - 118s 8ms/sample - loss: 0.2736 - acc: 0.9098 - val_loss: 0.3506 - val_acc: 0.8842
# Epoch 28/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2689 - acc: 0.9096
# Epoch 00028: val_acc improved from 0.88422 to 0.89974, saving model to M2-weights-improvement-28-0.90.hdf5
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.2689 - acc: 0.9096 - val_loss: 0.2973 - val_acc: 0.8997
# Epoch 29/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2566 - acc: 0.9161
# Epoch 00029: val_acc did not improve from 0.89974
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.2566 - acc: 0.9161 - val_loss: 0.3989 - val_acc: 0.8596
# Epoch 30/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2466 - acc: 0.9211
# Epoch 00030: val_acc did not improve from 0.89974
# 13910/13910 [==============================] - 105s 8ms/sample - loss: 0.2466 - acc: 0.9211 - val_loss: 0.4208 - val_acc: 0.8480
# Epoch 31/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2430 - acc: 0.9226
# Epoch 00031: val_acc did not improve from 0.89974
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.2430 - acc: 0.9226 - val_loss: 0.3531 - val_acc: 0.8777
# Epoch 32/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2291 - acc: 0.9275
# Epoch 00032: val_acc improved from 0.89974 to 0.90427, saving model to M2-weights-improvement-32-0.90.hdf5
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.2291 - acc: 0.9275 - val_loss: 0.2900 - val_acc: 0.9043
# Epoch 33/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2225 - acc: 0.9288
# Epoch 00033: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.2225 - acc: 0.9288 - val_loss: 0.3894 - val_acc: 0.8571
# Epoch 34/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2222 - acc: 0.9338
# Epoch 00034: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.2222 - acc: 0.9338 - val_loss: 0.3812 - val_acc: 0.8752
# Epoch 35/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.2047 - acc: 0.9390
# Epoch 00035: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 112s 8ms/sample - loss: 0.2047 - acc: 0.9390 - val_loss: 0.3301 - val_acc: 0.8836
# Epoch 36/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1999 - acc: 0.9400
# Epoch 00036: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.1999 - acc: 0.9400 - val_loss: 0.3451 - val_acc: 0.8752
# Epoch 37/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1935 - acc: 0.9446
# Epoch 00037: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 104s 8ms/sample - loss: 0.1935 - acc: 0.9446 - val_loss: 0.3040 - val_acc: 0.8965
# Epoch 38/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1893 - acc: 0.9448
# Epoch 00038: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 107s 8ms/sample - loss: 0.1893 - acc: 0.9448 - val_loss: 0.3262 - val_acc: 0.9036
# Epoch 39/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1816 - acc: 0.9477
# Epoch 00039: val_acc did not improve from 0.90427
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.1816 - acc: 0.9477 - val_loss: 0.4631 - val_acc: 0.8603
# Epoch 40/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1777 - acc: 0.9500
# Epoch 00040: val_acc did not improve from 0.90427
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13910/13910 [==============================] - 102s 7ms/sample - loss: 0.1777 - acc: 0.9500 - val_loss: 0.3653 - val_acc: 0.8920
# Epoch 41/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1119 - acc: 0.9789
# Epoch 00041: val_acc improved from 0.90427 to 0.91850, saving model to M2-weights-improvement-41-0.92.hdf5
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.1119 - acc: 0.9789 - val_loss: 0.2611 - val_acc: 0.9185
# Epoch 42/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.1012 - acc: 0.9827
# Epoch 00042: val_acc did not improve from 0.91850
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.1012 - acc: 0.9827 - val_loss: 0.2645 - val_acc: 0.9159
# Epoch 43/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0961 - acc: 0.9839
# Epoch 00043: val_acc improved from 0.91850 to 0.92561, saving model to M2-weights-improvement-43-0.93.hdf5
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.0961 - acc: 0.9839 - val_loss: 0.2651 - val_acc: 0.9256
# Epoch 44/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0922 - acc: 0.9851
# Epoch 00044: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 106s 8ms/sample - loss: 0.0922 - acc: 0.9851 - val_loss: 0.2680 - val_acc: 0.9172
# Epoch 45/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0884 - acc: 0.9867
# Epoch 00045: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 103s 7ms/sample - loss: 0.0884 - acc: 0.9867 - val_loss: 0.2665 - val_acc: 0.9185
# Epoch 46/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0857 - acc: 0.9872
# Epoch 00046: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.0857 - acc: 0.9872 - val_loss: 0.2849 - val_acc: 0.9101
# Epoch 47/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0813 - acc: 0.9891
# Epoch 00047: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 112s 8ms/sample - loss: 0.0813 - acc: 0.9891 - val_loss: 0.2739 - val_acc: 0.9120
# Epoch 48/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0807 - acc: 0.9886
# Epoch 00048: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 113s 8ms/sample - loss: 0.0807 - acc: 0.9886 - val_loss: 0.2697 - val_acc: 0.9153
# Epoch 49/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0777 - acc: 0.9897
# Epoch 00049: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 110s 8ms/sample - loss: 0.0777 - acc: 0.9897 - val_loss: 0.2763 - val_acc: 0.9230
# Epoch 50/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0750 - acc: 0.9906
# Epoch 00050: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 111s 8ms/sample - loss: 0.0750 - acc: 0.9906 - val_loss: 0.3202 - val_acc: 0.9082
# Epoch 51/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0733 - acc: 0.9907
# Epoch 00051: val_acc did not improve from 0.92561
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 13910/13910 [==============================] - 98s 7ms/sample - loss: 0.0733 - acc: 0.9907 - val_loss: 0.3079 - val_acc: 0.9069
# Epoch 52/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0661 - acc: 0.9950
# Epoch 00052: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 92s 7ms/sample - loss: 0.0661 - acc: 0.9950 - val_loss: 0.2764 - val_acc: 0.9217
# Epoch 53/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0636 - acc: 0.9961
# Epoch 00053: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 85s 6ms/sample - loss: 0.0636 - acc: 0.9961 - val_loss: 0.2669 - val_acc: 0.9243
# Epoch 54/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0633 - acc: 0.9961
# Epoch 00054: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 85s 6ms/sample - loss: 0.0633 - acc: 0.9961 - val_loss: 0.2682 - val_acc: 0.9224
# Epoch 55/200
# 13910/13910 [==============================] - ETA: 0s - loss: 0.0619 - acc: 0.9960
# Epoch 00055: val_acc did not improve from 0.92561
# 13910/13910 [==============================] - 88s 6ms/sample - loss: 0.0619 - acc: 0.9960 - val_loss: 0.2705 - val_acc: 0.9243
# Epoch 00055: early stopping

# %%
########画图
import matplotlib
import matplotlib.pyplot as plt
from sklearn import metrics
acc = history.history['acc']     #获取训练集准确性数据
val_acc = history.history['val_acc']    #获取验证集准确性数据
loss = history.history['loss']          #获取训练集错误值数据
val_loss = history.history['val_loss']  #获取验证集错误值数据
font = {
    'family' : 'Bitstream Vera Sans',
    'weight' : 'bold',
    'size'   : 18
}
matplotlib.rc('font', **font)

width = 12
height = 8
plt.figure(figsize=(width, height))
epochs = range(1,len(acc)+1)
plt.plot(epochs,acc,'r',label='Trainning acc',linewidth=2)     #以epochs为横坐标，以训练集准确性为纵坐标
plt.plot(epochs,val_acc,'b--',label='Vaildation acc',linewidth=2) #以epochs为横坐标，以验证集准确性为纵坐标
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Accuracy values)')
plt.xlabel('Training epochs')
plt.ylim([0.6,1])

plt.figure(figsize=(width, height))
plt.plot(epochs,loss,'r',label='Trainning loss',linewidth=2)
plt.plot(epochs,val_loss,'b--',label='Vaildation loss',linewidth=2)
plt.legend(loc='best', shadow=True)   #绘制图例，即标明图中的线段代表何种含义
plt.title("Training session's progress over epochs")
plt.ylabel('Training Progress (Loss values)')
plt.xlabel('Training epochs') 
plt.show()    #显示所有图表
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#model2.load_weights("M2-weights-improvement-45-0.97.hdf5")
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])
scores = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# confusion matrix
Y_pred=model.predict_classes(X_test)
print(Y_pred.shape)
# Out:
# acc: 93.19%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-cc54c5cf9ee2> in <module>
#       7
#       8 # confusion matrix
# ----> 9 Y_pred=model.predict_classes(X_test)
#      10 print(Y_pred.shape)
#
# AttributeError: 'Functional' object has no attribute 'predict_classes'

# %%
from sklearn.metrics import confusion_matrix
cm_cmap=plt.cm.Greens
cm = confusion_matrix(Y_test,Y_pred)


print('| Confusion Matrix |')
print('--------------------')
print('\n {}'.format(cm))
class_labels=['Pre','Mid','Post']
# plot confusin matrix
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
plt.show()
class_labels=[0,1,2]
# get classification report
print('| Classifiction Report |')
print('-------------------------')
classification_report = metrics.classification_report(Y_test,Y_pred,labels =class_labels)
# store report in results


print(classification_report)
